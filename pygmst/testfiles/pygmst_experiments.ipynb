# %%
nato = "whisky foxtrot tango"

# %%
w, t, f = (_ for _ in nato.split())

# %%
t
# Out:
# 'foxtrot'

# %%
import re
from sortedcontainers import SortedDict

def cluster(feature_f: str, clusters: int, min_length: int = 10000):  # $gc_out, $bins
    gc_hash: Dict[int, int] = dict()
    cut_off_points = list()
    num_of_seq = 0
    total_length = 0
    header_to_cod_GC = dict()

    with open(feature_f, "r") as GC:
        # read in probuild output, line by line.  Should be fasta input.
        for line in GC:
            # if the line is a fasta header in the form of '>(Reference sequence name)\t(number) (number)
            # if (text := re.search(pattern="^>(.*?)\t(\d+)\s+(\d+)", string=line)): # switch to this?  only support python>=3.8?
            text = re.search(pattern="^>(.*?)\t(\d+)\s+(\d+)", string=line)
            if text:
                header = text.group(1)  # Reference name
                length = int(text.group(2))  # length of sequence?
                GC = int(text.group(3))  # must be GC percentage
                header_re = re.search(
                    pattern="^(.*?)\t", string=line
                )  # Dont get this one - didn't we already extract just this capture group?
                if header_re:
                    header = header_re.group(1)
                header_to_cod_GC[header] = GC
                num_of_seq += 1
                total_length += length
                if GC in gc_hash:
                    gc_hash[GC] += length
                else:
                    gc_hash[GC] = length

    sorted_GC = SortedDict(gc_hash)  # sort the gc_hash dictionary by keys
    min_GC = sorted_GC.values()[0]
    max_GC = sorted_GC.values()[-1]
    print(f"min_GC={min_GC} max_GC={max_GC} total_seq_length={total_length}\n")

    previous = 0
    for key in sorted_GC:
        gc_hash[key] += previous

        if previous < total_length / 3 and gc_hash[key] >= total_length / 3:
            one_third = key
        if previous < total_length / 3 * 2 and gc_hash[key] >= total_length / 3 * 2:
            two_third = key
        if previous < total_length / 2 and gc_hash[key] >= total_length / 2:
            one_half = key
        previous = gc_hash[key]
        # TODO: uncomment when we have logging fixed
        # log.info(f"({one_third})->({gc_hash[one_third]})\n")
        # log.info(f"({one_half})->({gc_hash[one_half]})\n")
        # log.info(f"({two_third})->({gc_hash[two_third]})\n")

    if clusters == 0:
        # cluster number is not specified by user
        # automatically choose cluster number.
        if two_third - one_third > 3:
            clusters = 3
        else:
            clusters = 1
    if clusters == 3:
        if (
            (two_third - one_third) < 1
            or (max_GC - two_third) < 1
            or (one_third - min_GC) < 1
        ):
            # &Log( "Total number of sequences is not enough for training in 3 clusters!\n" )
            clusters = 1
        else:
            if gc_hash[one_third] > min_length:
                cut_off_points.extend((min_GC, one_third, two_third, max_GC))
            else:
                # &Log( "Total length of sequences is not enough for training in 3 clusters!\n" )
                clusters = 2

    if clusters == 2:
        if gc_hash[one_half] > min_length:
            cut_off_points.extend((min_GC, one_half, max_GC))
        else:
            # &Log( "Total length of sequences is not enough for training in 2 clusters!\n" )
            pass

    if clusters == 1:
        cut_off_points.extend((min_GC, max_GC))
    return clusters, cut_off_points, header_to_cod_GC

# %%
gc_out = "initial.meta.list.feature"
clusters = 3
min_length: int = 10000

# %%
bin_num, cutoffs, seq_GC = cluster(feature_f=gc_out, clusters=clusters)
# Out:
# min_GC=232 max_GC=2039 total_seq_length=9926700

# %%
bin_num
# Out:
# 1

# %%
cutoffs
# Out:
# [232, 2039]

# %%
seq_GC
# Out:
# {'>98_1132_1457_1035_31.3:NM_001020461 hypothetical_protein': 31,
#  '>256_1713_1713_1458_34.2:NM_001020458 membrane_transporter__predicted_': 34,
#  '>130_684_742_555_35.1:NM_001020454 isomerase': 35,
#  '>365_1153_1471_789_33.7:NM_001020453 GDT1_like_protein': 34,
#  '>138_1220_1372_1083_37.8:NM_001020452 L_asparaginase__predicted_': 38,
#  '>185_1183_1294_999_36.3:NM_001020451 hydroxyacid_dehydrogenase__predicted_': 36,
#  '>231_1211_1498_981_35.7:NM_001020450 cell_surface_glycoprotein__predicted___DIPSY_family': 36,
#  '>74_1825_1907_1752_38.0:NM_001020449 amidase__predicted_': 38,
#  '>95_1378_2086_1284_34.6:NM_001020448 nitric_oxide_dioxygenase__predicted_': 35,
#  '>1_1986_2109_1986_37.0:NM_001020447 urea_transporter__predicted_': 37,
#  '>318_2840_3200_2523_35.2:NM_001020445 sulfate_transporter__predicted_': 35,
#  '>16_627_732_612_36.2:NM_001020444 HHE_domain_cation_binding_protein__predicted_': 36,
#  '>15_1325_1469_1311_34.9:NM_001020443 alpha_galactosidase__melibiase': 35,
#  '>316_1008_1363_693_35.1:NM_001020442 protein_L_isoaspartate_O_methyltransferase_Pcm2__predicted_': 35,
#  '>58_408_605_351_37.1:NM_001020441 conserved_fungal_protein': 37,
#  '>321_1979_2255_1659_37.8:NM_001020440 proline_specific_plasma_membrane_permease_Put4__predicted_': 38,
#  '>644_2407_2658_1764_37.2:NM_001020439 cationic_amino_acid_transporter_Cat1': 37,
#  '>225_1715_1983_1491_38.1:NM_001020438 aldehyde_dehydrogenase__predicted_': 38,
#  '>276_1052_1192_777_38.5:NM_001020437 3_oxoacyl__acyl_carrier_protein_reductase__predicted_': 39,
#  '>1889_3403_3573_1515_37.3:NM_001020436 membrane_transporter__predicted_': 37,
#  '>126_479_633_354_33.4:NM_001020435 sequence_orphan': 33,
#  '>180_1196_1251_1017_39.0:NM_001020434 1_aminocyclopropane_1_carboxylate_deaminase__predicted_': 39,
#  '>483_863_1033_381_36.3:NM_001020432 MMF1_like_protein': 36,
#  '>1402_3144_3273_1743_38.4:NM_001020431 amino_acid_permease_Isp5': 38,
#  '>386_1198_1310_813_39.5:NM_001020430 serine_acetyltransferase__predicted_': 40,
#  '>201_1547_1872_1347_38.2:NM_001020429 aminotransferase': 38,
#  '>370_1617_2157_1248_37.1:NM_001020428 alanine_racemase__predicted_': 37,
#  '>395_2740_2811_2346_38.2:NM_001020427 zinc_finger_protein_Klf1': 38,
#  '>319_1842_2074_1524_37.2:NM_001020426 nicotinic_acid_plasma_membrane_transporter__predicted_': 37,
#  '>625_1650_1763_1026_38.4:NM_001020425 esterase_lipase__predicted_': 38,
#  '>983_2788_2908_1806_38.1:NM_001020424 phosphoprotein_phosphatase__predicted_': 38,
#  '>991_2694_3178_1704_36.5:NM_001020423 gamma_aminobutyric_acid_polyamine_transporter': 37,
#  '>932_2704_2906_1773_37.1:NM_001020422 purine_transporter__predicted_': 37,
#  '>67_480_507_414_34.5:NM_001020421 S__hydroxymethyl_glutathione_synthase': 35,
#  '>94_618_1424_525_34.6:NM_001020419 hypothetical_protein': 35,
#  '>496_3051_3334_2556_37.7:NM_001020418 glutathione_transporter_Pgt1': 38,
#  '>1111_3180_3631_2070_42.2:NM_001020417 sequence_orphan': 42,
#  '>265_6252_6534_5988_40.4:NM_001020416 multidomain_vesicle_coat_component_Sec16__predicted_': 40,
#  '>163_1014_1608_852_33.5:NM_001020415 RNA_binding_protein__CCR4_NOT_complex_subunit_Rcd1': 34,
#  '>129_1058_1212_930_36.3:NM_001020414 mitochondrial_S_adenosylmethionine_dependent_methyltransferase__predicted_': 36,
#  '>296_1186_1303_891_42.8:NM_001020413 pyridoxine_biosynthesis_protein': 43,
#  '>673_1047_1403_375_35.9:NM_001020412 ribonucleotide_reductase__RNR__inhibitor': 36,
#  '>319_2715_2953_2397_39.2:NM_001020411 histone_lysine_methyltransferase_Set2': 39,
#  '>61_4875_5150_4815_39.2:NM_001020410 SNF2_family_helicase_Ino80': 39,
#  '>44_121_376_78_39.3:NM_001020409 60S_ribosomal_protein_L41': 39,
#  '>436_2970_3608_2535_36.3:NM_001020408 ATP_dependent_DNA_helicase_Chl1__predicted_': 36,
#  '>122_601_854_480_35.8:NM_001020407 GARP_complex_subunit_Vps51__predicted_': 36,
#  '>219_2768_2925_2550_37.6:NM_001020406 trehalose_phosphate_synthase_Tps2__predicted_': 38,
#  '>190_738_1036_549_34.5:NM_001020405 mitochondrial_sulfhydryl_oxidase__predicted_': 35,
#  '>83_460_708_378_30.9:NM_001020404 hypothetical_protein': 31,
#  '>258_1400_1483_1143_39.1:NM_001020403 FEN_1_endonuclease_Rad2': 39,
#  '>703_1323_1605_621_34.9:NM_001020402 Mpv17_PMP22_family_protein_1__predicted_': 35,
#  '>126_1235_1375_1110_37.4:NM_001020401 RNA_binding_protein_Rnp24': 37,
#  '>409_1134_1384_726_36.6:NM_001020400 Maf_like_protein': 37,
#  '>81_296_653_216_37.0:NM_001020399 mRNA_export_protein_Dss1': 37,
#  '>599_4765_5028_4167_37.8:NM_001020398 ATP_dependent_DNA_helicase_Hrp3': 38,
#  '>67_2154_2217_2088_38.5:NM_001020397 U1_snRNP_associated_protein_Usp104': 39,
#  '>162_992_1113_831_37.2:NM_001020396 ATP_binding_protein_Fet5__predicted_': 37,
#  '>184_1029_1632_846_37.4:NM_001020395 conserved_fungal_protein': 37,
#  '>105_1526_2306_1422_35.5:NM_001020394 SAGA_complex_subunit_Spt20': 36,
#  '>189_1565_1657_1377_39.2:NM_001020393 translation_initiation_factor_eIF2B_gamma_subunit__predicted_': 39,
#  '>579_2180_2552_1602_37.7:NM_001020392 amidophosphoribosyltransferase_Ade4': 38,
#  '>373_2178_2474_1806_33.2:NM_001020391 sequence_orphan': 33,
#  '>130_924_1140_795_37.7:NM_001020390 siroheme_synthase__predicted_': 38,
#  '>76_1062_1213_987_38.6:NM_001020389 translation_initiation_factor_eIF3i': 39,
#  '>439_1233_1268_795_33.8:NM_001020388 cis_prenyltransferase__predicted_': 34,
#  '>331_2442_2585_2112_36.2:NM_001020387 F_box_WD_repeat_protein_Pop2': 36,
#  '>71_1006_1513_936_35.2:NM_001020386 glycerophosphoryl_diester_phosphodiesterase__predicted_': 35,
#  '>90_5525_5647_5436_35.7:NM_001020385 Sec7_domain_protein__ARF_GEF__predicted_': 36,
#  '>159_2192_2371_2034_33.4:NM_001020384 mitochondrial_inner_membrane_protein__predicted_': 33,
#  '>925_2568_2635_1644_36.5:NM_001020383 Vid24_family_protein__predicted_': 37,
#  '>1_3825_3959_3825_38.9:NM_001020382 tripeptidyl_peptidase_II_Tpp2': 39,
#  '>125_1384_1465_1260_38.1:NM_001020381 mitochondrial_GTPase_Mtg2__predicted_': 38,
#  '>76_591_638_516_36.8:NM_001020380 mitochondrial_intermembrane_space_protein_sorting_protein__predicted_': 37,
#  '>348_2120_2543_1773_37.6:NM_001020379 protein_phosphatase_regulatory_subunit_Paa1': 38,
#  '>42_467_1618_426_36.8:NM_001020378 myosin_II_light_chain': 37,
#  '>347_1465_1799_1119_40.1:NM_001020377 phospho_2_dehydro_3_deoxyheptonate_aldolase__predicted_': 40,
#  '>30_680_854_651_36.8:NM_001020376 U2AF_small_subunit__U2AF_23': 37,
#  '>801_2888_3157_2088_33.7:NM_001020375 ski_complex_interacting_GTPase__predicted_': 34,
#  '>72_278_720_207_36.2:NM_001020374 heat_shock_protein_Hsp9': 36,
#  '>83_1444_1672_1362_35.9:NM_001020373 ZIP_zinc_transporter_1__predicted_': 36,
#  '>202_879_1222_678_35.1:NM_001020372 2_OG_Fe_II__oxygenase_superfamily_protein_Ofd2': 35,
#  '>85_438_550_354_38.7:NM_001020371 60S_ribosomal_protein_L22': 39,
#  '>1077_2843_3019_1767_36.9:NM_001020370 conserved_eukaryotic_protein': 37,
#  '>467_1999_2322_1533_38.7:NM_001020369 cell_wall_protein_Gas5__1_3_beta_glucanosyltransferase__predicted_': 39,
#  '>143_631_2883_489_39.1:NM_001020368 conserved_eukaryotic_protein': 39,
#  '>329_3157_3506_2829_36.7:NM_001020367 guanyl_nucleotide_exchange_factor__predicted_': 37,
#  '>113_601_915_489_34.2:NM_001020366 VanZ_like_family_protein': 34,
#  '>183_1094_1429_912_34.3:NM_001020365 protein_tyrosine_phosphatase_Pyp3': 34,
#  '>62_1630_1746_1569_33.3:NM_001020364 Smc5_6_complex_non_SMC_subunit_Nse6': 33,
#  '>61_744_1424_684_34.5:NM_001020363 V_type_ATPase_V1_subunit_E__predicted_': 35,
#  '>148_1344_1751_1197_34.9:NM_001020362 MADS_box_transcription_factor_Map1': 35,
#  '>148_4119_4314_3972_37.7:NM_001020361 ubiquitin_protein_ligase_E3': 38,
#  '>57_503_707_447_35.7:NM_001020360 ubiquitin_conjugating_enzyme_Ubc13': 36,
#  '>78_863_1098_786_32.2:NM_001020359 chromosome_segregation_protein_Pcs1': 32,
#  '>207_3920_4082_3714_36.1:NM_001020358 C2_domain_protein': 36,
#  '>85_726_855_642_35.5:NM_001020356 26S_proteasome_regulatory_particle_assembly_protein__predicted_': 36,
#  '>1160_2602_2972_1443_37.8:NM_001020355 transcription_factor__zf_fungal_binuclear_cluster_type__predicted_': 38,
#  '>237_737_1155_501_38.0:NM_001020354 sequence_orphan': 38,
#  '>75_2648_3105_2574_43.4:NM_001020353 cofilin_tropomyosin_family_protein_abp1': 43,
#  '>99_2660_2696_2562_36.2:NM_001020352 dipeptidyl_peptidase__predicted_': 36,
#  '>56_1666_4795_1611_38.3:NM_001020351 F1_ATPase_alpha_subunit': 38,
#  '>124_1944_2558_1821_35.3:NM_001020350 RFC_related_checkpoint_protein_Rad17': 35,
#  '>292_1185_1806_894_39.0:NM_001020349 clr6_L_associated_factor_1_Laf1': 39,
#  '>54_2258_2729_2205_37.5:NM_001020348 polyphosphate_synthetase__predicted_': 38,
#  '>491_1480_1619_990_34.7:NM_001020347 Nudix_family_hydrolase': 35,
#  '>102_659_1163_558_32.2:NM_001020345 mug5_protein': 32,
#  '>443_2377_2566_1935_37.1:NM_001020344 membrane_transporter__predicted_': 37,
#  '>554_1477_1956_924_35.9:NM_001020343 poly_A__binding_protein_Nab2__predicted_': 36,
#  '>71_2605_3233_2535_37.1:NM_001020342 LEM_domain_protein_Man1__Sad1_interacting_factor__predicted_': 37,
#  '>340_1143_1708_804_35.5:NM_001020341 hypothetical_protein': 36,
#  '>29_289_1066_261_33.5:NM_001020339 DASH_complex_subunit_Dad3': 34,
#  '>507_3737_3964_3231_36.2:NM_001020338 Smc5_6_complex_SMC_subunit_Smc5': 36,
#  '>84_818_4252_735_38.8:NM_001020337 DUF1770_family_protein': 39,
#  '>738_2162_2349_1425_40.2:NM_001020336 4_aminobutyrate_aminotransferase__GABA_transaminase_': 40,
#  '>106_1164_1164_1059_40.7:NM_001020334 Dhp1p_interacting_protein_Din1': 41,
#  '>100_429_516_330_37.2:NM_001020333 DNA_replication_factor_C_complex_subunit_Ctf8__predicted_': 37,
#  '>79_630_740_552_36.2:NM_001020332 U3_snoRNP_associated_protein_Imp3__predicted_': 36,
#  '>134_9817_10097_9684_36.7:NM_001020331 E3_ubiquitin_protein_ligase': 37,
#  '>119_1336_1623_1218_35.9:NM_001020330 poly_A__polymerase_Cid1': 36,
#  '>458_2593_2837_2136_38.4:NM_001020328 tyrosine_phosphatase_Pyp2': 38,
#  '>558_4559_4643_4002_33.8:NM_001020326 retrotransposable_element': 34,
#  '>191_451_637_261_38.9:NM_001020325 mitochondrial_conserved_eukaryotic_protein': 39,
#  '>525_920_1541_396_34.7:NM_001020324 yippee_like_protein': 35,
#  '>484_3270_3418_2787_38.9:NM_001020323 guanyl_nucleotide_exchange_factor_Sec74__predicted_': 39,
#  '>1_594_1333_594_34.7:NM_001020322 hypothetical_protein': 35,
#  '>249_1478_1657_1230_41.7:NM_001020321 pyruvate_dehydrogenase_e1_component_alpha_subunit_Pda1__predicted_': 42,
#  '>518_1636_1929_1119_38.5:NM_001020320 enoyl__acyl_carrier_protein__reductase__predicted_': 39,
#  '>494_841_1195_348_42.6:NM_001020319 sequence_orphan': 43,
#  '>38_673_781_636_47.7:NM_001020318 monomeric_2_3_bisphosphoglycerate__BPG__dependent_phosphoglycerate_mutase__PGAM___Gpm1': 48,
#  '>265_1230_1324_966_38.8:NM_001020317 glucose_1_dehydrogenase__NADP____predicted_': 39,
#  '>462_3395_3448_2934_37.2:NM_001020316 hypothetical_protein': 37,
#  '>177_3272_3458_3096_36.6:NM_001020315 GTPase_activating_protein_Gyp51__predicted_': 37,
#  '>39_1691_1887_1653_39.2:NM_001020314 tyrosine_phosphatase_Pyp1': 39,
#  '>824_1141_1879_318_39.0:NM_001020313 hypothetical_protein': 39,
#  '>110_1180_1315_1071_37.7:NM_001020312 conserved_eukaryotic_protein': 38,
#  '>165_3500_3713_3336_42.2:NM_001020311 cytoplasmic_leucine_tRNA_ligase_Lrs1__predicted_': 42,
#  '>74_1303_1478_1230_44.2:NM_001020309 translation_elongation_factor_EF_1_gamma_subunit': 44,
#  '>1_816_1402_816_35.5:NM_001020308 mitochondrial_ribosomal_protein_subunit_Mrps9__predicted_': 36,
#  '>86_1510_1869_1425_40.9:NM_001020307 pseudouridylate_synthase_Cbf5__predicted_': 41,
#  '>227_658_899_432_35.2:NM_001020306 myosin_I_light_chain_Cam2': 35,
#  '>128_1195_1287_1068_35.5:NM_001020305 hypothetical_protein': 36,
#  '>199_609_2248_411_36.6:NM_001020304 mediator_complex_subunit_Srb6': 37,
#  '>39_1505_1614_1467_39.4:NM_001020303 ubiquitin_protein_ligase_E4': 39,
#  '>173_784_1154_612_36.3:NM_001020302 rRNA_exonuclease_Rrp17__predicted_': 36,
#  '>205_1875_2666_1671_36.0:NM_001020301 RNA_polymerase_I_upstream_activation_factor_complex_subunit_Rrn5': 36,
#  '>292_3201_5802_2910_39.8:NM_001020300 Rho_type_GTPase_activating_protein_Rga3': 40,
#  '>227_679_1090_453_38.4:NM_001020299 sequence_orphan': 38,
#  '>557_1264_1297_708_37.8:NM_001020298 urease_accessory_protein_UreF__predicted_': 38,
#  '>159_1199_2057_1041_39.0:NM_001020297 peroxin_3_peroxisome_import_protein__predicted_': 39,
#  '>276_1628_1684_1353_40.4:NM_001020296 cytoplasmic_serine_tRNA_ligase_Srs1__predicted_': 40,
#  '>337_2247_2838_1911_42.6:NM_001020295 halotolerence_protein_4': 43,
#  '>116_559_1014_444_36.9:NM_001020294 mitocondrial_FUN14_family_protein': 37,
#  '>89_1384_1538_1296_39.7:NM_001020293 Clr6_histone_deacetylase_complex_subunit_Prw1': 40,
#  '>303_3593_6325_3291_36.2:NM_001020292 Ca2__Mn2__transporting_P_type_ATPase_P5_type_Cta5': 36,
#  '>120_1754_2026_1635_39.2:NM_001020291 elongator_complex__histone_acetyltransferase_subunit_Elp3__predicted_': 39,
#  '>179_3778_4006_3600_39.0:NM_001020290 ATP_dependent_DNA_helicase_Snf21': 39,
#  '>229_765_837_537_34.0:NM_001020289 sequence_orphan': 34,
#  '>1_468_965_468_39.0:NM_001020288 ubiquitin_conjugating_enzyme_Ubc14__predicted_': 39,
#  '>341_667_890_327_32.9:NM_001020287 alkyltransferase_like_protein_Atl1': 33,
#  '>116_469_607_354_36.0:NM_001020286 60S_ribosomal_protein_L30': 36,
#  '>627_4937_5034_4311_37.3:NM_001020285 MAP_kinase_kinase_kinase_Win1': 37,
#  '>104_1279_1591_1176_37.4:NM_001020284 ethanol_hypersensitive_mutant_protein_Etd1': 37,
#  '>78_1256_1546_1179_42.4:NM_001020283 translation_initiation_factor_eIF4A__predicted_': 42,
#  '>388_3864_4239_3477_38.9:NM_001020282 RhoGEF_Rgf2': 39,
#  '>124_1314_2211_1191_37.1:NM_001020281 alpha_1_6_mannosyltransferase_Och1': 37,
#  '>213_3071_4105_2859_34.3:NM_001020280 sequence_orphan': 34,
#  '>184_2322_2603_2139_37.7:NM_001020279 hypothetical_protein': 38,
#  '>138_1244_1440_1107_37.0:NM_001020278 Astra_associated_protein_1_Asa1': 37,
#  '>347_1702_1878_1356_40.5:NM_001020277 vacuolar_serine_protease_Psp3__predicted_': 41,
#  '>673_1524_2000_852_35.2:NM_001020276 PQ_loop_protein': 35,
#  '>203_2032_2442_1830_38.8:NM_001020275 transcription_factor_Hsf1': 39,
#  '>109_2094_2454_1986_38.2:NM_001020274 Set3_complex_subunit_Snt1': 38,
#  '>10_1020_1134_1011_34.6:NM_001020273 conserved_fungal_protein': 35,
#  '>66_1517_2102_1452_40.8:NM_001020272 ARF_GTPase_activating_protein__predicted_': 41,
#  '>171_2726_2980_2556_38.3:NM_001020271 1_phosphatidylinositol_4_kinase_Pik1': 38,
#  '>505_2445_3406_1941_36.0:NM_001020269 serine_threonine_protein_kinase_Sck2': 36,
#  '>97_675_1086_579_40.0:NM_001020268 ribosome_biogenesis_protein_rlp24': 40,
#  '>960_3539_3895_2580_39.8:NM_001020266 histone_lysine_methyltransferase_Set3': 40,
#  '>48_1898_2152_1851_40.6:NM_001020265 mitochondrial_type_I__2Fe_2S__ferredoxin_Etp1__cytochrome_oxidase_cofactor_Cox15__fusion': 41,
#  '>53_2182_2435_2130_42.0:NM_001020264 kexin': 42,
#  '>106_399_1162_294_34.5:NM_001020263 RNA_polymerase_I_upstream_activation_factor_complex_subunit_Rrn10': 35,
#  '>1346_2506_2823_1161_36.4:NM_001020262 Ran_GAP_Rna1': 36,
#  '>485_1483_2878_999_33.8:NM_001020261 alpha_1_2_galactosyltransferase_Gmh3': 34,
#  '>69_623_1280_555_35.7:NM_001020260 Rer1_family_protein__predicted_': 36,
#  '>107_1000_1182_894_39.2:NM_001020259 superoxide_dismutase_copper_chaperone_Ccs1': 39,
#  '>155_730_1023_576_41.7:NM_001020258 ThiJ_domain_protein': 42,
#  '>233_892_1966_660_38.2:NM_001020257 RNA_binding_protein': 38,
#  '>122_1246_2015_1125_35.2:NM_001020256 triose_phosphate_transporter__predicted_': 35,
#  '>97_438_525_342_45.1:NM_001020255 60S_ribosomal_protein_L31': 45,
#  '>193_1215_1276_1023_39.7:NM_001020254 type_I_protein_arginine_N_methyltransferase_Rmt1': 40,
#  '>50_3997_4277_3948_38.2:NM_001020253 nucleoporin_Nup155': 38,
#  '>443_1297_1442_855_36.1:NM_001020252 ribosome_biogenesis_protein__G_pathc_domain__PINX1_family__predicted_': 36,
#  '>772_2094_2251_1323_36.2:NM_001020251 ribosome_biogenesis_protein_Ytm1__predicted_': 36,
#  '>57_2075_2191_2019_38.6:NM_001020250 serine_threonine_protein_kinase_Ppk16__predicted_': 39,
#  '>324_1748_2119_1425_37.7:NM_001020249 microtubule_protein': 38,
#  '>421_2280_2311_1860_33.9:NM_001020248 GTPase_activating_protein__predicted_': 34,
#  '>2291_4303_5164_2013_34.5:NM_001020247 RhoGAP__GTPase_activator_towards_Rho_Rac_Cdc42_like_small_GTPases__predicted_': 35,
#  '>1_1053_2291_1053_34.7:NM_001020246 meiotic_recombination_protein_Rec24': 35,
#  '>90_527_799_438_32.6:NM_001020245 mitochondrial_ribosomal_protein_subunit_L25__predicted_': 33,
#  '>41_2011_2306_1971_40.6:NM_001020244 lipin_Ned1': 41,
#  '>347_964_1286_618_35.3:NM_001020243 COP9_signalosome_complex_subunit_7a__predicted_': 35,
#  '>426_2933_3130_2508_39.9:NM_001020242 urease_Ure2': 40,
#  '>312_1397_2194_1086_33.5:NM_001020241 conserved_fungal_protein': 34,
#  '>1137_2702_2821_1566_38.1:NM_001020240 acetyl_CoA_hydrolase__predicted_': 38,
#  '>223_795_2661_573_35.2:NM_001020239 pyridoxamine_5__phosphate_oxidase__predicted_': 35,
#  '>228_1199_1743_972_36.1:NM_001020238 checkpoint_clamp_complex_protein_Rad1': 36,
#  '>709_2403_2519_1695_33.7:NM_001020237 DUF1716_family_protein': 34,
#  '>516_1880_2098_1365_34.6:NM_001020236 SAGA_complex_histone_acetyltransferase_catalytic_subunit_Gcn5': 35,
#  '>297_1271_1440_975_33.2:NM_001020234 ubiquitin_specific_cysteine_protease__OTU_family__Otu2': 33,
#  '>1_609_701_609_35.2:NM_001020233 ribosome_biogenesis_protein__predicted_': 35,
#  '>505_1176_1409_672_35.6:NM_001020231 mitochondrial_ribosomal_protein_subunit_S18__predicted_': 36,
#  '>751_2364_2455_1614_37.2:NM_001020230 chromatin_silencing_protein_Clr2': 37,
#  '>234_1940_2336_1707_42.2:NM_001020229 vitamin_H_transporter_Vth1': 42,
#  '>1049_2935_3121_1887_37.4:NM_001020228 vitamin_H_transporter': 37,
#  '>93_578_810_486_37.5:NM_001020227 V_type_ATPase_V0_subunit_c__proteolipid_subunit_': 38,
#  '>96_2516_2692_2421_36.9:NM_001020226 U3_snoRNP_associated_protein_Nan1__predicted_': 37,
#  '>247_462_761_216_37.7:NM_001020225 DNA_directed_RNA_polymerase_I__II__and_III_subunit_Rpb10': 38,
#  '>217_921_1650_705_35.9:NM_001020224 GTPase_Ypt4': 36,
#  '>55_291_513_237_36.4:NM_001020223 sequence_orphan': 36,
#  '>1_1587_1683_1587_35.1:NM_001020221 Noc2p_Noc3p_complex_subunit_Noc2_family__predicted_': 35,
#  '>477_1748_2031_1272_37.8:NM_001020220 COP9_signalosome_complex_subunit_12__predicted_': 38,
#  '>188_934_1261_747_34.8:NM_001020219 ESCRT_I_complex_subunit_Vps28': 35,
#  '>350_1186_1428_837_36.2:NM_001020218 UbiE_family_methyltransferase__predicted_': 36,
#  '>117_2039_2302_1923_39.7:NM_001020217 CCR4_Not_complex_subunit_Not3_5__predicted_': 40,
#  '>279_2237_2292_1959_37.7:NM_001020216 mitochondrial_GTPase_involved_in_translation_Guf1__predicted_': 38,
#  '>216_1286_1377_1071_39.0:NM_001020215 cyclophilin_family_peptidyl_prolyl_cis_trans_isomerase_Wis2': 39,
#  '>140_463_1252_324_35.8:NM_001020214 transcription_elongation_factor__Elf1_family__predicted_': 36,
#  '>63_722_1886_660_35.2:NM_001020213 uracil_phosphoribosyltransferase__predicted_': 35,
#  '>59_280_1546_222_36.2:NM_001020212 conserved_fungal_protein__with_meiosis_specific_splicing': 36,
#  '>38_1408_1786_1371_38.2:NM_001020211 AAA_family_ATPase_Rvb1': 38,
#  '>86_397_397_312_29.4:NM_001020210 hypothetical_protein': 29,
#  '>40_3531_3655_3492_39.3:NM_001020209 ribosome_biogenesis_protein_Rrp12__predicted_': 39,
#  '>109_1275_1545_1167_44.7:NM_001020208 60S_ribosomal_protein_L3': 45,
#  '>497_625_848_129_34.9:NM_001020207 M_factor_precursor_Mfm1': 35,
#  '>484_1050_1543_567_37.4:NM_001020206 phosphatidylglycerol_phosphatidylinositol_transfer_protein': 37,
#  '>61_1377_1946_1317_37.4:NM_001020205 malic_acid_transport_protein_Mae1': 37,
#  '>226_1557_1687_1332_36.8:NM_001020204 19S_proteasome_regulatory_subunit_Rpn502': 37,
#  '>1_708_1995_708_34.2:NM_001020202 SMN_family_protein_Yip11': 34,
#  '>108_482_807_375_35.9:NM_001020201 zinc_finger_protein': 36,
#  '>121_1428_2522_1308_36.2:NM_001020200 AMSH_like_protease': 36,
#  '>284_604_761_321_32.7:NM_001020199 signal_recognition_particle_subunit_Srp14': 33,
#  '>206_1168_1894_963_34.7:NM_001020198 Atg8_deconjugator_Atg4__predicted_': 35,
#  '>257_1216_1533_960_33.0:NM_001020197 zinc_finger_protein': 33,
#  '>306_1082_1207_777_35.0:NM_001020196 rhomboid_family_protease': 35,
#  '>301_2472_2775_2172_37.0:NM_001020195 CTD_phosphatase_Fcp1': 37,
#  '>150_335_592_186_33.7:NM_001020194 40S_ribosomal_protein_S30': 34,
#  '>1185_6665_7102_5481_36.7:NM_001020193 1_3_beta_glucan_synthase_subunit_Bgs3': 37,
#  '>346_1974_2220_1629_39.4:NM_001020192 cell_wall_protein_Gas1__1_3_beta_glucanosyltransferase__predicted_': 39,
#  '>158_2611_2703_2454_36.8:NM_001020191 TPR_repeat_protein__TTC27_family': 37,
#  '>105_410_502_306_35.6:NM_001020190 glutaredoxin_Grx1': 36,
#  '>272_736_973_465_32.6:NM_001020189 zf_HIT_protein_Hit1__predicted_': 33,
#  '>217_1392_1523_1176_39.1:NM_001020188 WD_repeat_containing_protein': 39,
#  '>263_634_958_372_33.2:NM_001020187 conserved_fungal_protein': 33,
#  '>1779_5882_6104_4104_36.3:NM_001020186 P_type_ATPase__predicted_': 36,
#  '>69_1793_2070_1725_45.4:NM_001020185 actin_assembly_factor': 45,
#  '>88_543_626_456_42.6:NM_001020184 nascent_polypeptide_associated_complex_beta_subunit': 43,
#  '>123_3101_3244_2979_40.1:NM_001020183 GYF_domain_protein': 40,
#  '>168_1010_1231_843_35.3:NM_001020182 kinetochore_protein_fta1': 35,
#  '>89_1498_2120_1410_37.9:NM_001020181 septin_Spn1': 38,
#  '>520_1533_2095_1014_37.4:NM_001020180 mannosyltransferase_complex_subunit__Anp_family_Mnn9__predicted_': 37,
#  '>165_2747_2925_2583_36.6:NM_001020179 ribosome_biogenesis_protein_Noc1__predicted_': 37,
#  '>1077_2273_2539_1197_33.7:NM_001020178 sequence_orphan': 34,
#  '>280_2556_2917_2277_37.7:NM_001020177 autophagy_associated_protein_kinase_regulatory_subunit_Atg13': 38,
#  '>156_1322_1556_1167_34.2:NM_001020176 ribosome_small_subunit_biogenesis_protein__BUD22_family__predicted_': 34,
#  '>318_977_1022_660_33.5:NM_001020175 mitochondrial_lipoate_protein_ligase__predicted_': 34,
#  '>260_1237_1412_978_35.1:NM_001020174 protein_phosphatase_type_2A__intrinsic_regulator__predicted_': 35,
#  '>1_858_1073_858_37.7:NM_001020173 tRNA_2__O_ribose_methyltransferase__predicted_': 38,
#  '>51_1454_1596_1404_38.7:NM_001020172 aspartyl_aminopeptidase_Aap1': 39,
#  '>98_1459_1541_1362_37.7:NM_001020170 C_24_28__sterol_reductase_Sts1': 38,
#  '>23_436_629_414_36.0:NM_001020169 actin_depolymerizing_factor__cofilin': 36,
#  '>1_1707_1781_1707_37.8:NM_001020168 UPF0061_family_protein': 38,
#  '>129_992_1496_864_34.8:NM_001020167 checkpoint_clamp_complex_protein_Hus1': 35,
#  '>377_2491_2738_2115_36.8:NM_001020166 eIF2_alpha_kinase_Hri1': 37,
#  '>448_4566_4680_4119_33.7:NM_001020165 formin_Fus1': 34,
#  '>139_636_3425_498_35.9:NM_001020163 small_histone_ubiquitination_factor_Shf1': 36,
#  '>293_2992_4062_2700_36.0:NM_001020162 phosphoinositide_phospholipase_C_Plc1': 36,
#  '>19_1824_1941_1806_39.2:NM_001020161 U2_snRNP_associated_protein_Sap145__predicted_': 39,
#  '>148_1407_1498_1260_34.8:NM_001020160 rRNA_processing_protein_Rrp16__predicted_': 35,
#  '>215_2995_3112_2781_40.4:NM_001020159 COPII_cargo_receptor_Sec24_Sfb2_subunit': 40,
#  '>419_1819_1891_1401_33.2:NM_001020158 replication_termination_factor_Rtf1': 33,
#  '>204_881_1073_678_37.3:NM_001020157 20S_proteasome_component_beta_6': 37,
#  '>417_3092_3372_2676_38.2:NM_001020156 alpha_alpha_trehalose_phosphate_synthase__predicted_': 38,
#  '>372_1523_1815_1152_38.6:NM_001020155 triose_phosphate_transporter__predicted_': 39,
#  '>465_1511_1699_1047_34.0:NM_001020150 pheromone_p_factor_receptor': 34,
#  '>36_656_817_621_37.5:NM_001020149 SMR_and_DUF1771_domain_protein__predicted_': 38,
#  '>194_988_2910_795_33.2:NM_001020148 sequence_orphan': 33,
#  '>151_1614_1714_1464_34.9:NM_001020147 ESCRT_I_complex_subunit_Vps23': 35,
#  '>176_532_1759_357_37.7:NM_001020146 DUF423_protein': 38,
#  '>165_773_920_609_37.0:NM_001020145 adenylyl_sulfate_kinase__predicted_': 37,
#  '>72_536_1216_465_33.7:NM_001020144 box_H_ACA_snoRNP_complex_subunit_Nhp2': 34,
#  '>50_1663_1663_1614_40.8:NM_001020143 Cdc14_related_protein_phosphatase_Clp1_Flp1': 41,
#  '>69_347_608_279_36.3:NM_001020141 ubiquinol_cytochrome_c_reductase_complex_subunit_7': 36,
#  '>64_912_1260_849_37.8:NM_001020140 prohibitin_Phb1__predicted_': 38,
#  '>93_1151_1386_1059_35.2:NM_001020139 serine_threonine_protein_phosphatase_2A_activator_2': 35,
#  '>60_587_1161_528_35.6:NM_001020138 mitochondrial_mRNA_processing_protein_Cox24__predicted_': 36,
#  '>578_1645_1804_1068_34.4:NM_001020137 splicing_associated_factor_Saf3': 34,
#  '>354_839_1087_486_33.3:NM_001020136 conserved_fungal_protein': 33,
#  '>54_659_797_606_38.8:NM_001020134 PPPDE_peptidase_family__predicted_': 39,
#  '>111_959_1229_849_38.3:NM_001020133 delta_1_pyrroline_5_carboxylate_reductase__predicted_': 38,
#  '>190_531_825_342_39.1:NM_001020132 DNA_directed_RNA_polymerase_II_complex_subunit_Rpb9': 39,
#  '>198_2318_2596_2121_38.9:NM_001020131 septin_ring_organizing_protein': 39,
#  '>202_2199_2370_1998_37.2:NM_001020130 stress_activated_MAP_kinase_interacting_protein_Sin1': 37,
#  '>57_1361_1468_1305_36.9:NM_001020129 transcription_factor_TFIIE_alpha_subunit__TFIIEA__Tfa1': 37,
#  '>61_1155_1334_1095_34.8:NM_001020128 WD_repeat_protein_involved_in_autophagy_Atg18c': 35,
#  '>50_2455_2627_2406_35.6:NM_001020127 phosphatidylinositol_3_kinase_Pik3': 36,
#  '>109_1191_1315_1083_32.3:NM_001020126 dynein_intermediate_light_chain_Dil1': 32,
#  '>776_3382_3512_2607_34.0:NM_001020125 Tel2_Rad_5_Clk_2_family_protein_Tel2': 34,
#  '>137_1543_1667_1407_39.1:NM_001020124 mRNP_complex__predicted_': 39,
#  '>74_2140_2285_2067_36.4:NM_001020123 tRNA__cytosine_5___methyltransferase': 36,
#  '>352_2550_2628_2199_33.9:NM_001020122 cation_diffusion_family_zinc_membrane_transporter_Cis4': 34,
#  '>62_1978_2064_1917_37.5:NM_001020121 DNA_replication_pre_initiation_complex_subunit_Cdc45': 38,
#  '>482_2860_3085_2379_39.6:NM_001020119 secretory_pathway_protein_Sec18__predicted_': 40,
#  '>145_681_718_537_34.8:NM_001020118 sequence_orphan': 35,
#  '>22_942_1212_921_34.8:NM_001020117 variant_protein_kinase_19_family_protein': 35,
#  '>244_5163_5435_4920_36.3:NM_001020116 histidine_kinase_Mak1': 36,
#  '>123_1787_2081_1665_35.6:NM_001020115 kinesin_like_protein_Klp3': 36,
#  '>113_1102_1404_990_35.1:NM_001020114 mo25_family_protein_Pmo25': 35,
#  '>333_2066_2488_1734_35.7:NM_001020113 mannosyltransferase_complex_subunit_Alg9__predicted_': 36,
#  '>139_549_870_411_39.7:NM_001020112 histone_H3_h3_1': 40,
#  '>149_460_772_312_35.3:NM_001020111 histone_H4_h4_1': 35,
#  '>91_4812_4926_4722_39.3:NM_001020110 pentafunctional_aromatic_polypeptide_Aro1__predicted_': 39,
#  '>125_1426_1936_1302_36.4:NM_001020109 translation_release_factor_eRF1': 36,
#  '>930_1967_2588_1038_35.2:NM_001020108 Golgi_GDP_mannose_transporter_Vrg4__predicted_': 35,
#  '>366_1715_2801_1350_36.4:NM_001020107 6_phosphofructo_2_kinase__predicted_': 36,
#  '>101_640_2425_540_36.4:NM_001020106 sister_chromatid_cohesion_protein__predicted_': 36,
#  '>357_2462_4268_2106_34.5:NM_001020105 Golgi_transport_complex_subunit_Cog1__predicted_': 35,
#  '>363_1898_1929_1536_35.7:NM_001020104 kinesin_like_protein_Klp8': 36,
#  '>1093_2763_3538_1671_36.8:NM_001020103 CDK_inhibitor_Srw1': 37,
#  '>1509_2333_3059_825_34.4:NM_001020102 ribose_5_phosphate_isomerase__predicted_': 34,
#  '>26_484_595_459_43.8:NM_001020101 40S_ribosomal_protein_S11': 44,
#  '>148_1527_1668_1380_36.0:NM_001020100 pig_W': 36,
#  '>400_1524_1785_1125_34.5:NM_001020099 RNA_polymerase_III_transcription_factor_TFIIIA': 35,
#  '>405_1082_2912_678_33.9:NM_001020098 mitochondrial_DNAJ_domain_protein_Jac1__predicted_': 34,
#  '>429_1376_1651_948_33.6:NM_001020097 ATP_binding_protein': 34,
#  '>89_2566_3935_2478_36.1:NM_001020096 AP_3_adaptor_complex_subunit_Apl5__predicted_': 36,
#  '>463_4590_4890_4128_35.4:NM_001020095 ATP_dependent_DNA_helicase__predicted_': 35,
#  '>305_1603_1788_1299_39.7:NM_001020094 ornithine_decarboxylase_Spe1__predicted_': 40,
#  '>23_1327_1373_1305_42.3:NM_001020093 adenylosuccinate_synthetase_Ade2': 42,
#  '>157_906_1451_750_37.2:NM_001020092 Ino80_complex_subunit_Iec1': 37,
#  '>108_446_539_339_33.9:NM_001020091 sequence_orphan': 34,
#  '>359_1207_1567_849_40.5:NM_001020090 mitochondrial_outer_membrane_voltage_dependent_anion_selective_channel__predicted_': 41,
#  '>101_1474_1992_1374_37.0:NM_001020089 conserved_fungal_protein': 37,
#  '>206_2734_2888_2529_37.2:NM_001020088 sequence_orphan': 37,
#  '>188_1585_1778_1398_36.7:NM_001020087 mitochondrial_inheritance_GTPase__predicted_': 37,
#  '>207_620_956_414_31.9:NM_001020086 cornichon_family_protein_Erv14__predicted_': 32,
#  '>1_1353_1531_1353_37.3:NM_001020085 cofactor_for_methionyl_and_glutamyl_tRNA_synthetases__predicted_': 37,
#  '>152_784_825_633_33.8:NM_001020084 sequence_orphan': 34,
#  '>263_1219_1414_957_37.8:NM_001020083 deoxyhypusine_hydroxylase__predicted_': 38,
#  '>91_2298_2749_2208_36.9:NM_001020081 ATP_dependent_RNA_helicase_Hca4__predicted_': 37,
#  '>1_1503_4250_1503_36.0:NM_001020080 tRNA_nucleotidyltransferase__predicted_': 36,
#  '>185_2683_3509_2499_35.7:NM_001020079 inositol_polyphosphate_phosphatase__predicted_': 36,
#  '>33_728_1199_696_36.2:NM_001020078 pyridoxamine_5__phosphate_oxidase__predicted_': 36,
#  '>1334_5119_5439_3786_36.8:NM_001020077 mitochondrial_PPR_repeat_protein_Ppr5': 37,
#  '>258_1787_2036_1530_37.5:NM_001020076 conserved_protein_Mug157': 38,
#  '>112_555_555_444_39.8:NM_001020075 ribonuclease_H2_complex_subunit__predicted_': 40,
#  '>1_1998_2099_1998_38.3:NM_001020074 serine_threonine_protein_kinase_Ppk2__predicted_': 38,
#  '>206_928_1039_723_35.1:NM_001020073 hypothetical_protein': 35,
#  '>332_2248_2521_1917_34.5:NM_001020072 DNA_repair_protein_Rhp41': 35,
#  '>114_1373_1373_1260_35.6:NM_001020070 sequence_orphan': 36,
#  '>1_1038_1257_1038_35.1:NM_001020069 S_adenosylmethionine_transporter__predicted_': 35,
#  '>707_2077_2352_1371_34.1:NM_001020068 mitochondrial_tRNA_Ile__lysidine_synthetase_family__predicted_': 34,
#  '>791_1561_1962_771_34.9:NM_001020067 F_actin_capping_protein_alpha_subunit': 35,
#  '>202_621_698_420_35.1:NM_001020066 succinate_dehydrogenase_subunit_Emi5__predicted_': 35,
#  '>80_1540_1718_1461_36.4:NM_001020065 mitochondrial_intermediate_cleavage_peptidase_Icp55__predicted_': 36,
#  '>169_1380_1516_1212_32.7:NM_001020064 tubulin_tyrosine_ligase__predicted_': 33,
#  '>464_2095_2559_1632_35.0:NM_001020063 WD_repeat_containing_protein': 35,
#  '>68_775_816_708_37.7:NM_001020062 endoplasmic_reticulum_resident_protein_required_for_packaging_into_COPII_vesicles__predicted_': 38,
#  '>216_5159_5352_4944_36.0:NM_001020061 ubiquitin_protein_ligase_E3__predicted_': 36,
#  '>966_3782_4793_2817_37.8:NM_001020060 zds_family_protein_phosphatase_type_A_regulator_Zds1__predicted_': 38,
#  '>79_1575_1860_1497_40.2:NM_001020059 cytoskeletal_signaling_protein__predicted_': 40,
#  '>144_1535_3818_1392_36.2:NM_001020058 KAT5_family_histone_acetyltransferase_Mst1': 36,
#  '>471_2414_2626_1944_35.7:NM_001020057 mitochondrial_ATP_dependent_RNA_helicase_Rpm2': 36,
#  '>127_858_1028_732_36.4:NM_001020056 19S_proteasome_regulatory_subunit_Rpn10': 36,
#  '>216_2111_2207_1896_38.4:NM_001020055 ribonuclease_H70__predicted_': 38,
#  '>222_1175_1271_954_37.4:NM_001020054 iron_sulfur_cluster_assembly_ATPase_Nbp35__predicted_': 37,
#  '>112_1815_2002_1704_42.2:NM_001020053 translation_initiation_factor_eIF3d_Moe1': 42,
#  '>118_1161_1434_1044_37.7:NM_001020052 alpha_1_2_galactosyltransferase__predicted_': 38,
#  '>158_1669_1936_1512_38.7:NM_001020051 V_type_ATPase_V1_subunit_B': 39,
#  '>589_3177_3366_2589_35.2:NM_001020050 cargo_transport_protein_Ypp1__predicted_': 35,
#  '>464_1273_1443_810_38.8:NM_001020049 conserved_fungal_protein': 39,
#  '>45_3164_3324_3120_40.1:NM_001020048 RNA_polymerase_II_associated_Paf1_complex_subunit_Tpr1': 40,
#  '>138_869_1060_732_34.9:NM_001020046 neddylation_pathway_protein_But1': 35,
#  '>179_1570_1643_1392_42.5:NM_001020045 But2_family_protein': 43,
#  '>193_1344_1434_1152_40.8:NM_001020043 But2_family_protein': 41,
#  '>274_1431_1528_1158_34.6:NM_001020042 DUF890_family_protein': 35,
#  '>74_427_778_354_36.1:NM_001020041 Sm_snRNP_core_protein_Smd1': 36,
#  '>47_1072_1131_1026_40.4:NM_001020040 electron_transfer_flavoprotein_alpha_subunit__predicted_': 40,
#  '>267_590_753_324_36.3:NM_001020039 anaphase_promoting_complex_subunit_Apc14': 36,
#  '>131_421_1407_291_33.8:NM_001020038 4_alpha_hydroxytetrahydrobiopterin_dehydratase__predicted_': 34,
#  '>1724_3976_4033_2253_35.9:NM_001020037 RNA_binding_protein_involved_in_meiosis_Mei2': 36,
#  '>121_2373_2754_2253_35.5:NM_001020036 GRIP_domain_protein__predicted_': 36,
#  '>88_3246_3443_3159_36.1:NM_001020035 Ypt_Rab_specific_guanyl_nucleotide_exchange_factor__GEF__subunit_Ric1': 36,
#  '>76_771_3118_696_35.6:NM_001020034 CK2_family_regulatory_subunit_Ckb1': 36,
#  '>109_948_1085_840_37.5:NM_001020033 1_acylglycerol_3_phosphate_O_acyltransferase_Slc1__predicted_': 38,
#  '>59_2056_2357_1998_36.2:NM_001020032 anaphase_promoting_complex_subunit_Apc3': 36,
#  '>238_1014_1365_777_35.0:NM_001020031 alpha_aminoadipate_reductase_phosphopantetheinyl_transferase_Lys7': 35,
#  '>334_4545_4686_4212_42.3:NM_001020030 translation_initiation_factor_eIF4G': 42,
#  '>93_914_1242_822_32.8:NM_001020029 mediator_complex_subunit_Pmc3_Med27': 33,
#  '>262_1689_1949_1428_38.0:NM_001020028 mitochondrial_sorting_and_assembly_machinery_complex_subunit_Sam50__predicted_': 38,
#  '>139_1644_2062_1506_35.1:NM_001020027 glucosyltransferase_Alg8__predicted_': 35,
#  '>178_1146_1286_969_36.7:NM_001020026 mitochondrial_endodeoxyribonuclease_Pnu1': 37,
#  '>341_628_819_288_33.3:NM_001020025 TIM22_inner_membrane_protein_import_complex_subunit_Tim13__predicted_': 33,
#  '>1063_1878_2046_816_33.3:NM_001020024 G_protein_coupled_receptor_Stm1': 33,
#  '>715_1437_1493_723_35.9:NM_001020023 zf_C2H2_type_zinc_finger_protein_UBA_domain_protein': 36,
#  '>60_1019_1726_960_40.9:NM_001020022 VAMP_synaptobrevin_associated_protein_family_protein': 41,
#  '>379_1167_1529_789_37.2:NM_001020021 tethering_factor_for_nuclear_proteasome_Cut8': 37,
#  '>253_951_1036_699_34.5:NM_001020020 Pex19_protein__predicted_': 35,
#  '>143_427_1511_285_35.7:NM_001020019 sequence_orphan': 36,
#  '>121_780_855_660_37.1:NM_001020017 CIA30_protein__predicted_': 37,
#  '>487_1182_1453_696_34.2:NM_001020016 ESCRT_III_complex_subunit_Vps24': 34,
#  '>67_627_976_561_36.4:NM_001020015 p23_chaperone_protein_wos2': 36,
#  '>339_4622_4761_4284_36.8:NM_001020014 ABC_transporter_Ybt1': 37,
#  '>88_1089_1205_1002_38.6:NM_001020013 pyridoxal_reductase_Plr1': 39,
#  '>191_1735_2040_1545_38.3:NM_001020012 CENP_B_protein_1': 38,
#  '>117_1628_1908_1512_41.5:NM_001020011 aldehyde_dehydrogenase__predicted_': 42,
#  '>527_2371_2671_1845_34.3:NM_001020010 DNA_repair_protein': 34,
#  '>55_657_1849_603_34.7:NM_001020009 GTPase_Ypt2': 35,
#  '>82_1626_1919_1545_38.4:NM_001020008 threonine_synthase__predicted_': 38,
#  '>75_1016_2207_942_36.9:NM_001020007 sequence_orphan': 37,
#  '>99_665_932_567_37.1:NM_001020006 hypothetical_protein': 37,
#  '>260_2536_2677_2277_42.0:NM_001020005 3_isopropylmalate_dehydratase_Leu2__predicted_': 42,
#  '>1_300_608_300_37.5:NM_001020003 hypothetical_protein': 38,
#  '>381_1709_2144_1329_37.9:NM_001020002 transcription_factor_Sfp1__predicted_': 38,
#  '>54_1907_2063_1854_40.9:NM_001020001 tRNA_dihydrouridine_synthase_Dus3__predicted_': 41,
#  '>154_1167_1579_1014_37.2:NM_001020000 dihydroorotase_Ura2__predicted_': 37,
#  '>82_1179_1781_1098_43.4:NM_001019999 mRNA_export_factor_Srp2': 43,
#  '>303_905_1375_603_35.9:NM_001019998 Rho_family_GTPase_Rho2': 36,
#  '>301_3558_3705_3258_38.7:NM_001019997 conserved_fungal_protein': 39,
#  '>107_1126_1317_1020_34.6:NM_001019996 sequence_orphan': 35,
#  '>74_769_1301_696_38.1:NM_001019995 TATA_binding_protein__TBP_': 38,
#  '>78_2342_2433_2265_40.1:NM_001019993 cytoplasmic_cysteine_tRNA_ligase_Crs1__predicted_': 40,
#  '>165_677_1604_513_34.9:NM_001019992 peptide_methionine_sulfoxide_reductase__predicted_': 35,
#  '>249_1877_5537_1629_36.6:NM_001019989 U4_U6_x_U5_tri_snRNP_complex_subunit_Prp3__predicted_': 37,
#  '>285_1805_2010_1521_38.4:NM_001019988 F_box_protein_Pof11': 38,
#  '>153_4562_4696_4410_38.4:NM_001019987 glutathione_S_conjugate_exporting_ATPase_Abc4': 38,
#  '>48_710_1041_663_33.6:NM_001019986 translin': 34,
#  '>75_920_1006_846_34.5:NM_001019985 elongator_complex_associated_protein_Kti2__predicted_': 35,
#  '>99_5567_5681_5469_36.8:NM_001019984 Sec7_domain_protein__ARF_GEF_Sec72': 37,
#  '>210_1637_2501_1428_33.6:NM_001019983 RNA_binding_protein__predicted_': 34,
#  '>125_730_952_606_35.8:NM_001019982 Golgi_transport_protein_Sft2__predicted_': 36,
#  '>199_7392_7475_7194_37.9:NM_001019981 alpha_1_3_glucan_synthase_Mok11': 38,
#  '>1_4851_4973_4851_35.8:NM_001019979 guanyl_nucleotide_exchange_factor__predicted_': 36,
#  '>409_2088_2633_1680_37.6:NM_001019978 inorganic_phosphate_transporter__predicted_': 38,
#  '>930_1820_2972_891_35.5:NM_001019977 1_acyldihydroxyacetone_phosphate_reductase__predicted_': 36,
#  '>420_2540_2833_2121_37.4:NM_001019976 endo_1_3_beta_glucanase_Eng2': 37,
#  '>158_1432_2925_1275_37.1:NM_001019975 SWI_SNF_and_RSC_complex_subunit_Arp42': 37,
#  '>75_1088_2771_1014_38.1:NM_001019974 U1_snRNP_associated_protein_Usp108': 38,
#  '>216_1019_1454_804_35.9:NM_001019973 20S_proteasome_component_beta_2__predicted_': 36,
#  '>227_4204_4449_3978_38.3:NM_001019972 nucleoporin_Nup146': 38,
#  '>432_1553_1810_1122_37.7:NM_001019971 glycerol_3_phosphate_dehydrogenase_Gpd2': 38,
#  '>561_1979_2068_1419_36.3:NM_001019970 GTPase_activating_protein__predicted_': 36,
#  '>70_1092_1220_1023_37.7:NM_001019969 DNA_replication_factor_C_complex_subunit_Rfc2': 38,
#  '>152_1375_1375_1224_36.8:NM_001019968 PWWP_domain_protein__involved_in_chromatin_remodeling__predicted_': 37,
#  '>11_3511_3546_3501_40.2:NM_001019967 U2_snRNP_associated_protein_Sap155': 40,
#  '>347_1912_2174_1566_36.9:NM_001019966 Nramp_family_manganese_ion_transporter': 37,
#  '>160_1512_1772_1353_38.8:NM_001019965 dolichyl_diphospho_oligosaccharide_protein_glycosyltransferase_Ost1__predicted_': 39,
#  '>81_1169_1305_1089_39.3:NM_001019964 FKBP_type_peptidyl_prolyl_cis_trans_isomerase__predicted_': 39,
#  '>122_427_952_306_33.6:NM_001019963 sequence_orphan': 34,
#  '>528_1982_2210_1455_39.6:NM_001019962 aminotransferase': 40,
#  '>48_1373_1735_1326_34.8:NM_001019961 spindle_pole_body_protein_Nuf2': 35,
#  '>105_773_864_669_37.8:NM_001019960 ubiquitin_C_terminal_hydrolase_Uch1': 38,
#  '>82_567_980_486_38.1:NM_001019959 tropomyosin': 38,
#  '>45_2222_2527_2178_39.8:NM_001019957 translation_initiation_factor_eIF3b__p84_': 40,
#  '>365_3622_3830_3258_37.3:NM_001019956 kinesin_like_protein_Cut7': 37,
#  '>23_229_302_207_41.7:NM_001019955 40S_ribosomal_protein_S28': 42,
#  '>32_964_1297_933_40.1:NM_001019954 ATP_phosphoribosyltransferase': 40,
#  '>109_2484_2519_2376_35.2:NM_001019953 meiotic_recombination_protein_Rec10': 35,
#  '>310_1302_1646_993_37.5:NM_001019952 transcription_factor_Zip1': 38,
#  '>701_1477_1670_777_32.8:NM_001019951 mitochondrial_cruciform_cutting_endonuclease_Cce1': 33,
#  '>854_3376_3768_2523_35.9:NM_001019949 MS_ion_channel_protein_2__predicted_': 36,
#  '>40_642_711_603_45.1:NM_001019948 40S_ribosomal_protein_S8': 45,
#  '>63_1346_1465_1284_42.1:NM_001019947 UBX_domain_protein_Ubx2': 42,
#  '>116_1054_2078_939_35.8:NM_001019946 PAK_related_kinase_Ppk11': 36,
#  '>68_667_3090_600_35.1:NM_001019945 V_type_ATPase_V0_subunit_c____predicted_': 35,
#  '>459_1556_1768_1098_35.1:NM_001019944 tRNA_2__phosphotransferase_Tpt1__predicted_': 35,
#  '>116_841_1192_726_37.3:NM_001019943 RNA_binding_protein_Rbp28': 37,
#  '>262_762_990_501_36.6:NM_001019942 sequence_orphan': 37,
#  '>16_666_1372_651_35.1:NM_001019941 DUF1640_family_protein': 35,
#  '>112_843_843_732_37.8:NM_001019940 conserved_fungal_protein': 38,
#  '>79_2862_3267_2784_36.7:NM_001019939 ribonuclease_II__RNB__family__predicted_': 37,
#  '>67_1449_1707_1383_37.7:NM_001019938 rRNA_methyltransferase__predicted_': 38,
#  '>55_459_934_405_36.8:NM_001019937 cornichon_family_protein__predicted_': 37,
#  '>520_897_1114_378_32.9:NM_001019936 conserved_eukaryotic_protein': 33,
#  '>73_420_491_348_36.8:NM_001019935 Sm_snRNP_core_protein_Smd2': 37,
#  '>148_1125_1199_978_38.4:NM_001019933 iron_sulfur_cluster_biogenesis_IBA57_like_protein': 38,
#  '>50_1453_2097_1404_37.0:NM_001019932 translation_initiation_factor_eIF2B_delta_subunit__predicted_': 37,
#  '>158_1708_2472_1551_37.7:NM_001019931 cyclophilin_family_peptidyl_prolyl_cis_trans_isomerase_Cyp8': 38,
#  '>189_818_1024_630_36.3:NM_001019930 L_azetidine_2_carboxylic_acid_acetyltransferase': 36,
#  '>705_1220_1481_516_38.4:NM_001019929 transcription_factor_Pcr1': 38,
#  '>290_1312_1455_1023_43.8:NM_001019927 aldose_reductase_ARK13_family_YakC': 44,
#  '>98_2446_3025_2349_38.9:NM_001019926 transcription_factor__zf_fungal_binuclear_cluster_type__predicted_': 39,
#  '>549_1265_1403_717_39.4:NM_001019925 hydantoin_racemase_family__predicted_': 39,
#  '>403_1431_1635_1029_41.3:NM_001019924 allantoicase__predicted_': 41,
#  '>560_2428_2795_1869_42.5:NM_001019923 iron_transport_multicopper_oxidase_Fio1': 43,
#  '>265_1458_1763_1194_42.5:NM_001019922 iron_permease_Fip1': 43,
#  '>236_991_1943_756_34.3:NM_001019921 ThiJ_domain_protein': 34,
#  '>25_2460_2716_2436_41.7:NM_001019920 ribonucleoside_reductase_large_subunit_Cdc22': 42,
#  '>403_1011_1716_609_38.9:NM_001019919 Rho_family_GTPase_Rho1': 39,
#  '>325_2457_3026_2133_37.2:NM_001019918 TRP_like_ion_channel_Pkd2': 37,
#  '>247_1983_2183_1737_37.1:NM_001019917 ATP_dependent_RNA_helicase_Has1__predicted_': 37,
#  '>86_4183_4413_4098_38.5:NM_001019916 transcription_elongation_factor_Spt6__predicted_': 39,
#  '>111_3170_3251_3060_38.6:NM_001019915 mediator_of_replication_checkpoint_1': 39,
#  '>1_270_317_270_44.4:NM_001019914 40S_ribosomal_protein_S25': 44,
#  '>142_1116_1218_975_37.9:NM_001019913 conserved_eukaryotic_protein': 38,
#  '>33_782_1979_750_37.4:NM_001019912 conserved_fungal_protein': 37,
#  '>38_5191_5465_5154_39.4:NM_001019911 DEAD_DEAH_box_helicase': 39,
#  '>372_1028_1221_657_35.5:NM_001019910 zf_CCHC_type_zinc_finger_protein': 36,
#  '>1_318_380_318_39.2:NM_001019909 sequence_orphan': 39,
#  '>1019_2587_3159_1569_39.6:NM_001019908 transcription_factor_zf_C2H2_type__predicted_': 40,
#  '>204_569_748_366_31.6:NM_001019907 mitochondrial_electron_carrier__predicted_': 32,
#  '>66_953_1194_888_36.0:NM_001019906 peptidase_family_A22': 36,
#  '>223_2319_2535_2097_37.6:NM_001019905 RNase_P_and_RNase_MRP_subunit__predicted_': 38,
#  '>318_1031_2165_714_36.9:NM_001019904 wybutosine_biosynthesis_protein_Tyw3__predicted_': 37,
#  '>411_1322_2304_912_35.9:NM_001019903 kinetochore_protein_mal2': 36,
#  '>1341_2534_3114_1194_36.3:NM_001019902 2_OG_Fe_II__oxygenase_superfamily_protein': 36,
#  '>412_1323_1884_912_38.7:NM_001019901 nucleotide_sugar_phosphatase__predicted_': 39,
#  '>386_2350_2659_1965_37.3:NM_001019900 transcription_factor__predicted_': 37,
#  '>54_824_1425_771_36.9:NM_001019899 trans_aconitate_3_methyltransferase__predicted_': 37,
#  '>165_920_1108_756_36.8:NM_001019898 trans_aconitate_3_methyltransferase__predicted_': 37,
#  '>1_1773_1978_1773_36.6:NM_001019897 conserved_fungal_protein': 37,
#  '>83_424_1729_342_33.1:NM_001019896 hypoxia_induced_family_protein': 33,
#  '>167_1606_3517_1440_37.2:NM_001019895 mitochondrial_serine_tRNA_ligase__predicted_': 37,
#  '>524_1876_1931_1353_36.7:NM_001019894 tRNA_pseudouridine_synthase__predicted_': 37,
#  '>341_1477_1731_1137_35.3:NM_001019893 mitochondrial_splicing_suppressor_Mss51__predicted_': 35,
#  '>1002_2552_2797_1551_37.1:NM_001019892 phosphatidylserine_decarboxylase_Psd2': 37,
#  '>68_871_1255_804_37.9:NM_001019891 Clr6_histone_deacetylase_complex_subunit_Sds3': 38,
#  '>9_509_856_501_36.9:NM_001019890 cytochrome_P450_regulator_Dap1': 37,
#  '>538_1248_2935_711_36.8:NM_001019889 inositol_phoshorylceramide_synthase_regulatory_subunit_Kei1__predicted_': 37,
#  '>97_3561_3867_3465_38.0:NM_001019888 mitochondrial_RNA_polymerase_Rpo41': 38,
#  '>1318_4215_4393_2898_38.6:NM_001019887 spore_wall_assembly_protein__predicted_': 39,
#  '>117_590_1049_474_41.2:NM_001019886 translation_elongation_factor_eIF5A__predicted_': 41,
#  '>399_1508_1815_1110_45.1:NM_001019885 gfo_idh_mocA_family_oxidoreductase__predicted_': 45,
#  '>445_1410_1654_966_39.8:NM_001019884 glucan_beta_glucosidase_Bgl2__predicted_': 40,
#  '>36_1553_1713_1518_38.4:NM_001019883 seven_transmembrane_receptor_protein__predicted_': 38,
#  '>385_2052_3088_1668_37.6:NM_001019882 telomere_end_binding_protein_Pot1': 38,
#  '>213_3668_3806_3456_39.6:NM_001019881 IPT_TIG_ankyrin_repeat_containing_transcription_regulator_of_fatty_acid_biosynthesis__predicted_': 40,
#  '>274_2643_2862_2370_35.6:NM_001019880 vacuolar_import_and_degradation_protein_Vid28__predicted_': 36,
#  '>469_2007_2243_1539_35.3:NM_001019879 CAF_assembly_factor__CAF_1__complex_subunit_B__Pcf2': 35,
#  '>339_1853_1945_1515_37.4:NM_001019878 DNA_replication_ATPase__predicted_': 37,
#  '>81_3272_3414_3192_36.0:NM_001019877 RecQ_type_DNA_helicase_Hrq1__predicted_': 36,
#  '>132_1043_1758_912_36.5:NM_001019876 mitochondrial_ribosomal_protein_subunit_L51_b__predicted_': 37,
#  '>126_4961_5343_4836_45.3:NM_001019875 SH3_domain_containing_protein': 45,
#  '>70_663_1089_594_36.6:NM_001019874 RNA_polymerase_II_CTD_phosphatase_Rtr1__predicted_': 37,
#  '>135_815_1024_681_37.0:NM_001019873 SNARE_Sec20__predicted_': 37,
#  '>255_1451_1907_1197_38.6:NM_001019872 cystathionine_gamma_synthase_like_protein': 39,
#  '>162_1931_1988_1770_41.5:NM_001019871 phenylalanine_tRNA_ligase_beta_subunit_Frs1__predicted_': 42,
#  '>67_660_801_594_45.3:NM_001019870 60S_ribosomal_protein_L16': 45,
#  '>69_1451_1451_1383_49.9:NM_001019869 translation_elongation_factor_EF_1_alpha_Ef1a_b': 50,
#  '>257_622_1228_366_35.3:NM_001019868 RNA_binding_protein__predicted_': 35,
#  '>66_404_489_339_42.9:NM_001019867 60S_ribosomal_protein_L34': 43,
#  '>220_975_1013_756_36.5:NM_001019866 ubiquitin_protein_ligase_E3__predicted_': 37,
#  '>62_1576_1940_1515_38.1:NM_001019865 MAPK_activated_protein_kinase_Cmk2': 38,
#  '>179_484_1090_306_32.5:NM_001019864 serine_palmitoyl_transferase_A_subunit__predicted_': 33,
#  '>297_2660_3225_2364_35.8:NM_001019863 alpha_mannosidase_Mnl1__predicted_': 36,
#  '>63_629_795_567_36.3:NM_001019862 adenine_phosphoribosyltransferase': 36,
#  '>719_2011_2011_1293_36.6:NM_001019861 phosphoprotein_phosphatase__predicted_': 37,
#  '>195_2648_2917_2454_40.8:NM_001019859 trehalose_6_phosphate_phosphatase_Tpp1': 41,
#  '>240_2468_2751_2229_39.8:NM_001019858 1_phosphatidylinositol_4_phosphate_5_kinase_Its3': 40,
#  '>213_962_2235_750_35.4:NM_001019857 Pot1_associated_protein_Poz1': 35,
#  '>259_1143_1432_885_35.8:NM_001019856 decaprenyl_diphosphate_synthase_subunit_2_Dlp1': 36,
#  '>454_1206_1494_753_36.5:NM_001019855 ubiquinone_biosynthesis_protein_Coq9__predicted_': 37,
#  '>435_3443_3576_3009_44.3:NM_001019854 vacuolar_carboxypeptidase_Y': 44,
#  '>273_1127_1213_855_38.6:NM_001019853 NADH_NADPH_dependent_indole_3_acetaldehyde_reductase_AKR3C2': 39,
#  '>165_1208_1734_1044_38.3:NM_001019852 sphingosine_hydroxylase_Scs7': 38,
#  '>656_2467_2673_1812_40.4:NM_001019851 RNA_binding_protein_Rsd1__predicted_': 40,
#  '>151_546_952_396_38.0:NM_001019850 histone_H2A_beta': 38,
#  '>224_1099_1270_876_38.2:NM_001019849 mitochondrial_citrate_transporter__predicted_': 38,
#  '>313_888_1665_576_34.1:NM_001019848 ureidoglycolate_hydrolase__predicted_': 34,
#  '>933_1895_2145_963_38.4:NM_001019847 chitin_deacetylase_Cda1': 38,
#  '>1887_4271_4350_2385_38.0:NM_001019846 MutL_family_mismatch_repair_protein_Pms1': 38,
#  '>85_3705_3899_3621_37.6:NM_001019844 U2_snRNP_associated_protein_Sap130__predicted_': 38,
#  '>39_902_1092_864_44.5:NM_001019843 40S_ribosomal_protein_S0B': 45,
#  '>113_7045_7336_6933_36.6:NM_001019841 histidine_kinase_Mak2': 37,
#  '>210_1379_2182_1170_34.0:NM_001019839 galactose_residue_biosynthesis_protein_Pvg2': 34,
#  '>654_2273_2317_1620_36.3:NM_001019838 mitochondrial_methionine_tRNA_ligase__predicted_': 36,
#  '>1_1389_1459_1389_40.5:NM_001019837 DNA_polymerase_delta_small_subunit_Cdc1': 41,
#  '>182_745_839_564_34.4:NM_001019836 hypothetical_protein': 34,
#  '>407_652_2150_246_37.7:NM_001019835 sequence_orphan': 38,
#  '>695_1873_2006_1179_36.2:NM_001019834 Obg_Like_ATPase__predicted_': 36,
#  '>287_1129_1413_843_34.8:NM_001019833 hypothetical_protein': 35,
#  '>194_1669_2137_1476_35.7:NM_001019832 glycosyl_hydrolase_family_13_protein': 36,
#  '>1656_2222_2270_567_35.7:NM_001019830 hypothetical_protein': 36,
#  '>1_2403_2780_2403_43.9:NM_001019827 sequence_orphan': 44,
#  '>1461_5417_5535_3957_38.6:NM_001019825 serine_threonine_protein_kinase_Ppk18__predicted_': 39,
#  '>1_1353_1539_1353_35.0:NM_001019824 tRNA__guanine__methyltransferase_Trm5': 35,
# ...
#  '>59_1057_1057_999_42.6:NM_001019590 RecA_family_ATPase_Dmc1': 43,
#  '>233_907_1044_675_38.0:NM_001019589 phospholipase__predicted_': 38,
#  '>56_1072_2374_1017_34.6:NM_001019588 conserved_fungal_protein': 35,
#  '>53_412_771_360_34.8:NM_001019586 tubulin_specific_chaperone_cofactor_A__Alp31': 35,
#  '>1022_1789_2257_768_37.7:NM_001019585 sorbose_reductase__predicted_': 38,
#  '>100_1173_1325_1074_39.0:NM_001019584 N_methyltransferase__predicted_': 39,
#  '>35_1099_1676_1065_40.0:NM_001019583 UBA_domain_protein_Dph1': 40,
#  '>738_2534_2719_1797_41.8:NM_001019582 nucleoporin_Nsp1': 42,
#  '>150_371_797_222_35.7:NM_001019581 DUF1748_family_protein': 36,
#  '>192_3167_4940_2976_38.7:NM_001019579 5__3__exoribonuclease_Dhp1': 39,
#  '>358_1326_1479_969_37.5:NM_001019578 amidohydrolase': 38,
#  '>169_2940_3622_2772_37.8:NM_001019577 centaurin_ADOP_ribosylation_factor_GTPase_activating_protein_family__predicted_': 38,
#  '>1_3828_4294_3828_37.5:NM_001019576 Rho_type_GTPase_activating_protein_Rga2__predicted_': 38,
#  '>99_542_1176_444_38.6:NM_001019575 Sm_snRNP_core_protein_Smb1': 39,
#  '>79_603_870_525_40:NM_001019574 60S_ribosomal_protein_L11': 40,
#  '>56_862_919_807_39.9:NM_001019573 S_adenosylmethionine_dependent_methyltransferase': 40,
#  '>21_5021_5234_5001_39.5:NM_001019572 clathrin_heavy_chain_Chc1__predicted_': 40,
#  '>71_601_731_531_45.6:NM_001019571 60S_ribosomal_protein_L20': 46,
#  '>976_1683_3261_708_39.4:NM_001019570 RecQ_mediated_genome_instability_protein_Rmi1__predicted_': 39,
#  '>169_1554_2749_1386_38.5:NM_001019569 adenine_DNA_glycosylase_Myh1': 39,
#  '>52_1626_1906_1575_40.1:NM_001019567 U3_snoRNP_associated_protein_Rrp9__predicted_': 40,
#  '>69_980_2199_912_38.0:NM_001019565 DNAJ_domain_protein_Erj5__predicted_': 38,
#  '>1_492_876_492_35.7:NM_001019564 Rab_GTPase_binding_protein_upregulated_in_meiosis_II__predicted_': 36,
#  '>404_1969_2204_1566_35.9:NM_001019563 mannosyl_oligosaccharide_1_2_alpha_mannosidase': 36,
#  '>72_791_872_720_48.0:NM_001019562 40S_ribosomal_protein_S6': 48,
#  '>407_1366_2253_960_34.5:NM_001019561 sequence_orphan': 35,
#  '>108_497_712_390_34.4:NM_001019560 DNA_directed_RNA_polymerase_III_complex_subunit_Rpc17': 34,
#  '>318_2537_2577_2220_39.7:NM_001019559 protein_O_mannosyltransferase_Ogm2': 40,
#  '>548_2212_2485_1665_37.5:NM_001019558 membrane_transporter__predicted_': 38,
#  '>756_7091_7495_6336_43.3:NM_001019557 glutamate_synthase_Glt1__predicted_': 43,
#  '>250_2457_3643_2208_38.1:NM_001019556 Holliday_junction_resolvase_subunit_Eme1': 38,
#  '>521_3751_3862_3231_40.7:NM_001019555 glycerophosphoryl_diester_phosphodiesterase_Gde1__predicted_': 41,
#  '>243_3953_4125_3711_41.8:NM_001019554 chitinase__predicted_': 42,
#  '>116_1891_2013_1776_38.9:NM_001019553 DNA_directed_RNA_polymerase_III_complex_subunit_Rpc82__predicted_': 39,
#  '>34_2481_2672_2448_39.1:NM_001019552 DNA_polymerase_alpha_accessory_factor_Mcl1': 39,
#  '>26_517_1345_492_36.9:NM_001019551 conserved_fungal_family': 37,
#  '>1_327_1595_327_35.4:NM_001019550 BC10_family_protein': 35,
#  '>248_1042_1156_795_37.4:NM_001019549 sequence_orphan': 37,
#  '>440_1936_2095_1497_36.1:NM_001019548 sequence_orphan': 36,
#  '>196_2241_4276_2046_38.4:NM_001019547 RNA_binding_protein__predicted_': 38,
#  '>45_1907_2177_1863_39.3:NM_001019545 Chs_five_related_protein_Cfr1': 39,
#  '>851_1216_2146_366_33.6:NM_001019544 SNAP_receptor__synaptobrevin_family': 34,
#  '>542_5605_5662_5064_35.9:NM_001019543 ATP_dependent_5__to_3__DNA_RNA_helicase_Sen1': 36,
#  '>35_484_539_450_45.8:NM_001019542 60S_ribosomal_protein_L24': 46,
#  '>138_1544_2659_1407_39.2:NM_001019541 ubiquitin_C_terminal_hydrolase_Ubp6': 39,
#  '>84_590_691_507_37.1:NM_001019540 ARP2_3_actin_organizing_complex_subunit_Arc4': 37,
#  '>156_3782_3920_3627_35.1:NM_001019539 pericentrin_Pcp1': 35,
#  '>312_1169_1229_858_36.9:NM_001019538 coenzyme_A_diphosphatase__predicted_': 37,
#  '>810_4766_5093_3957_35.5:NM_001019537 sporulation_protein_Spo7': 36,
#  '>68_1198_1501_1131_36.9:NM_001019536 histone_chaperone_Rtt106_like__predicted_': 37,
#  '>145_2112_2262_1968_38.2:NM_001019535 RNA_binding_protein_Nop9__predicted_': 38,
#  '>101_388_833_288_37.5:NM_001019534 hypothetical_protein': 38,
#  '>211_1812_1946_1602_40.4:NM_001019533 transcription_factor_Ace2': 40,
#  '>61_513_528_453_44.6:NM_001019532 ubiquitin_40S_ribosomal_protein_S31_fusion_protein': 45,
#  '>503_1087_1325_585_35.2:NM_001019531 hypothetical_protein': 35,
#  '>91_2517_3652_2427_39.3:NM_001019530 alpha_glucosidase_I_Gls1__predicted_': 39,
#  '>202_1521_1642_1320_40.1:NM_001019529 isocitrate_dehydrogenase_Idp1__predicted_': 40,
#  '>37_2379_2853_2343_37.6:NM_001019528 nuclear_cap_binding_complex_large_subunit__predicted_': 38,
#  '>41_3673_3810_3633_37.7:NM_001019526 TRAPP_complex_subunit_Trs120__predicted_': 38,
#  '>53_871_1078_819_40.2:NM_001019525 20S_proteasome_component_alpha_6_subunit_Pre5__predicted_': 40,
#  '>492_1778_2219_1287_37.4:NM_001019524 cardiolipin_specific_deacylase': 37,
#  '>405_3782_3959_3378_36.3:NM_001019523 cell_end_marker_Tea3': 36,
#  '>157_2484_2687_2328_36.6:NM_001019522 transcription_factor_Thi1': 37,
#  '>51_1217_1464_1167_37.2:NM_001019521 ribosome_biogenesis_protein_Nob1__predicted_': 37,
#  '>39_380_2124_342_31.3:NM_001019520 mitochondrial_inner_membrane_protein_involved_in_cytochrome_c_oxidase_assembly_Cox16__predicted_': 31,
#  '>93_527_665_435_36.2:NM_001019519 mitochondrial_ribosomal_protein_subunit_L19__predicted_': 36,
#  '>499_1731_1959_1233_36.0:NM_001019518 nicotinate_phosphoribosyltransferase__predicted_': 36,
#  '>31_5367_5367_5337_40.6:NM_001019517 nucleoporin_Nup98_and_Nup96': 41,
#  '>229_5412_5497_5184_36.8:NM_001019516 medial_ring_protein_Alm1': 37,
#  '>108_2501_2653_2394_37.2:NM_001019515 RNA_binding_splicing_factor__predicted_': 37,
#  '>34_1152_1584_1119_35.9:NM_001019514 UBA_domain_protein_Ucp14': 36,
#  '>157_813_1148_657_38.2:NM_001019513 manganese_superoxide_dismutase__predicted_': 38,
#  '>264_1652_1861_1389_36.2:NM_001019512 Clp1_interacting_protein_Nsk1': 36,
#  '>29_739_739_711_38.8:NM_001019511 3_oxoacyl__acyl_carrier_protein__reductase_Oar2__predicted_': 39,
#  '>42_461_580_420_43.6:NM_001019510 60S_ribosomal_protein_L23': 44,
#  '>323_916_977_594_37.7:NM_001019509 phosphoric_ester_hydrolase_Ssu72__predicted_': 38,
#  '>347_2326_2649_1980_38.3:NM_001019508 GTPase_activating_protein__predicted_': 38,
#  '>80_1579_1619_1500_39.8:NM_001019507 cytoplasmic_phenylalanine_tRNA_ligase_alpha_subunit_Frs2__predicted_': 40,
#  '>433_1737_1835_1305_36.8:NM_001019506 histone_deacetylase__class_I__Hos2': 37,
#  '>368_1219_1516_852_38.5:NM_001019505 chromatin_modification_related_protein': 39,
#  '>63_983_1138_921_40.3:NM_001019504 translation_initiation_factor_eIF2_alpha_subunit': 40,
#  '>86_814_1060_729_36.1:NM_001019503 exosomal_3__to_5__phosphorolytic_exoribonuclease_Rrp41__predicted_': 36,
#  '>478_2190_2493_1713_41.9:NM_001019502 pyruvate_decarboxylase__predicted_': 42,
#  '>205_4593_5346_4389_36.6:NM_001019501 CLASP_family_microtubule_associated_protein': 37,
#  '>1245_2330_6404_1086_35.9:NM_001019500 mitochondrial_tryptophan_tRNA_ligase_Msw1__predicted_': 36,
#  '>980_3280_3539_2301_39.8:NM_001019499 transcriptional_repressor_Sak1': 40,
#  '>241_1647_1796_1407_35.2:NM_001019496 ribosome_L32_lysine_methyltransferase_Set13': 35,
#  '>330_1337_1723_1008_35.8:NM_001019495 TatD_DNase_family_Scn1': 36,
#  '>555_1058_1106_504_35.1:NM_001019494 sequence_orphan': 35,
#  '>164_3472_3705_3309_40.3:NM_001019493 endocytosis_protein': 40,
#  '>172_4614_4786_4443_36.3:NM_001019492 DNA_polymerase_zeta_catalytic_subunit_Rev3__predicted_': 36,
#  '>110_1195_1879_1086_33.8:NM_001019491 mitochondrial_pyrimidine_nucleotide_transporter': 34,
#  '>111_3227_3387_3117_39.0:NM_001019489 sequence_orphan': 39,
#  '>163_1422_2199_1260_34.4:NM_001019488 structure_specific_endonuclease_subunit': 34,
#  '>134_862_1290_729_37.9:NM_001019487 glutathione_S_transferase_Gst3': 38,
#  '>55_636_744_582_38.7:NM_001019486 hypothetical_protein': 39,
#  '>163_795_908_633_35.7:NM_001019485 kinetochore_protein_Mis14': 36,
#  '>1_2916_3012_2916_38.7:NM_001019484 glycosylceramide_biosynthesis_protein__predicted_': 39,
#  '>52_504_733_453_37.3:NM_001019482 ubiquitin_40S_ribosomal_protein_S31_fusion_protein': 37,
#  '>959_2125_2437_1167_36.2:NM_001019481 sec14_cytosolic_factor_family__predicted_': 36,
#  '>94_561_744_468_36.9:NM_001019480 DASH_complex_subunit_Dam1': 37,
#  '>1_1122_1364_1122_39.0:NM_001019479 WD_repeat_protein_involved_in_autophagy_Atg18a': 39,
#  '>186_794_995_609_38.7:NM_001019478 pho88_family_protein__predicted_': 39,
#  '>173_1213_1407_1041_36.1:NM_001019477 conserved_eukaryotic_protein': 36,
#  '>94_909_1230_816_33.0:NM_001019476 metaxin_1__predicted_': 33,
#  '>201_707_921_507_34.0:NM_001019475 sequence_orphan': 34,
#  '>1_858_1123_858_33.7:NM_001019473 sequence_orphan': 34,
#  '>343_2334_2550_1992_36.5:NM_001019472 telomere_length_regulator': 37,
#  '>193_465_734_273_28.7:NM_001019470 DASH_complex_subunit_Dad1': 29,
#  '>101_712_1287_612_35.2:NM_001019469 Rho_family_GTPase_Rho4': 35,
#  '>424_2967_4043_2544_33.3:NM_001019468 zinc_finger_protein_Pep5_Vps11_like__predicted_': 33,
#  '>151_561_2515_411_34.5:NM_001019467 transcription_coactivator_PC4': 35,
#  '>518_3010_3432_2493_37.1:NM_001019466 DUF1212_family_protein': 37,
#  '>1_1395_1595_1395_37.9:NM_001019465 septin_Spn5': 38,
#  '>332_1321_4377_990_37.4:NM_001019464 ubiquitin_specific_cysteine_protease__OTU_family__Otu1': 37,
#  '>121_387_488_267_36.2:NM_001019463 mitochondrial_ribosomal_protein_subunit_Mrp10__predicted_': 36,
#  '>176_1579_1871_1404_42.4:NM_001019462 glycine_hydroxymethyltransferase__predicted_': 42,
#  '>127_2454_2556_2328_36.6:NM_001019461 ribosome_small_subunit_biogenesis_protein': 37,
#  '>95_886_978_792_38.0:NM_001019460 mitochondrial_ribosomal_protein_subunit_S2__predicted_': 38,
#  '>87_1511_2733_1425_36.3:NM_001019459 mitochondrial_threonine_tRNA_ligase__predicted_': 36,
#  '>402_2192_2317_1791_38.9:NM_001019458 vacuolar_carboxypeptidase__predicted_': 39,
#  '>1_5685_6069_5685_38.3:NM_001019457 1_3_beta_glucan_synthase_subunit_Bgs2': 38,
#  '>131_2500_2849_2370_43.5:NM_001019456 aconitate_hydratase__predicted_': 44,
#  '>78_2270_2327_2193_42.5:NM_001019455 conserved_protein_Mug20': 43,
#  '>457_822_1188_366_34.4:NM_001019454 sequence_orphan': 34,
#  '>1_201_252_201_37.6:NM_001019453 cytochrome_c_oxidase_subunit_VIII__predicted_': 38,
#  '>209_1390_2233_1182_38.7:NM_001019452 diphosphomevalonate_decarboxylase__predicted_': 39,
#  '>126_776_798_651_40.6:NM_001019451 cytochrome_c1_heme_lyase__predicted_': 41,
#  '>30_1835_1929_1806_37.2:NM_001019450 spindle_pole_body_docking_protein_Cut11': 37,
#  '>1055_2989_3422_1935_39.6:NM_001019449 phospholipase__predicted_': 40,
#  '>1_336_461_336_48.1:NM_001019448 sequence_orphan': 48,
#  '>1368_4940_5108_3573_39.4:NM_001019446 ATPase_with_bromodomain_protein__predicted_': 39,
#  '>59_850_1144_792_39.0:NM_001019445 hypothetical_protein': 39,
#  '>75_509_835_435_42.6:NM_001019444 40S_ribosomal_protein_S10': 43,
#  '>88_798_4336_711_36.5:NM_001019443 dolichol_phosphate_mannosyltransferase_catalytic_subunit_Dpm1': 37,
#  '>208_3111_3313_2904_36.7:NM_001019442 phosphatidylserine_decarboxylase_Psd3': 37,
#  '>343_1506_1963_1164_37.6:NM_001019441 glycine_decarboxylase_T_subunit__predicted_': 38,
#  '>348_1274_1676_927_36.3:NM_001019440 19S_proteasome_regulatory_subunit_Rpn11': 36,
#  '>100_456_697_357_35.0:NM_001019439 hypothetical_protein': 35,
#  '>128_844_1444_717_35.5:NM_001019438 repressor_of_RNA_polymerase_III_Maf1': 36,
#  '>720_1838_2142_1119_37.9:NM_001019435 MAP_kinase_Spk1': 38,
#  '>340_1095_2322_756_38.5:NM_001019434 uroporphyrinogen_III_synthase_Ups1': 39,
#  '>164_850_1097_687_38.8:NM_001019431 ribulose_phosphate_3_epimerase__predicted_': 39,
#  '>76_1164_1507_1089_39.6:NM_001019430 homoisocitrate_dehydrogenase': 40,
#  '>36_494_619_459_44.2:NM_001019429 40S_ribosomal_protein_S11': 44,
#  '>170_868_1153_699_35.7:NM_001019428 ER_chaperone_Rot1__predicted_': 36,
#  '>117_1124_1481_1008_38.4:NM_001019427 U2_snRNP_associated_RNA_binding_protein_Sap49': 38,
#  '>483_2576_4179_2094_39.1:NM_001019426 transcription_factor__predicted_': 39,
#  '>348_1571_1680_1224_38.9:NM_001019425 L_lactate_dehydrogenase__cytochrome_': 39,
#  '>46_1065_1315_1020_39.6:NM_001019424 esterase_lipase__predicted_': 40,
#  '>1077_3986_4149_2910_39.9:NM_001019422 alpha_glucosidase_Agl1': 40,
#  '>127_4317_4525_4191_38.2:NM_001019421 ABC_transporter_Pdr1': 38,
#  '>423_1472_1598_1050_37.5:NM_001019420 NADP_dependent_oxidoreductase__predicted_': 38,
#  '>267_1169_1354_903_43.5:NM_001019419 sequence_orphan': 44,
#  '>720_1670_2041_951_35.3:NM_001019418 DUF1749_family_protein': 35,
#  '>109_795_1205_687_34.9:NM_001019417 DNA_3_methyladenine_glycosylase_Mag1': 35,
#  '>191_1417_1537_1227_39.3:NM_001019416 agmatinase__predicted_': 39,
#  '>530_2161_2243_1632_38.7:NM_001019415 amino_acid_permease': 39,
#  '>64_3726_3865_3663_43.9:NM_001019413 cell_surface_glycoprotein__predicted_': 44,
#  '>977_1570_1964_594_35.5:NM_001019412 fungal_cellulose_binding_domain_protein': 36,
#  '>1035_3173_3353_2139_39.3:NM_001019411 copper_amine_oxidase_Cao1': 39,
#  '>296_4297_4297_4002_34.0:NM_001019410 retrotransposable_element': 34,
#  '>630_2183_2384_1554_39.7:NM_001019409 ammonium_transporter_Amt3': 40,
#  '>562_1608_1960_1047_36.6:NM_001019408 dehydrogenase__predicted_': 37,
#  '>506_1516_1759_1011_37.0:NM_001019407 flavonol_reductase_cinnamoyl_CoA_reductase_family': 37,
#  '>812_1918_5534_1107_38.4:NM_001019406 dihydrodiol_dehydrogenase__predicted_': 38,
#  '>422_3655_5799_3234_37.9:NM_001019405 alpha_mannosidase__predicted_': 38,
#  '>87_221_467_135_28.6:NM_001019403 M_factor_precursor_Mfm2': 29,
#  '>431_1081_1255_651_34.4:NM_001019402 phosphoglycerate_mutase_family': 34,
#  '>230_3907_5330_3678_38.4:NM_001019400 synaptotagmin_family_C2_domain_protein__Syn1': 38,
#  '>80_3715_3991_3636_37.7:NM_001019398 P_type_ATPase__calcium_transporting_Cta4': 38,
#  '>413_2794_2915_2382_35.9:NM_001019397 dipeptidyl_peptidase__predicted_': 36,
#  '>1_1020_1156_1020_37.7:NM_001019396 hypothetical_protein': 38,
#  '>277_1281_1448_1005_41.7:NM_001019395 glyoxylate_reductase__predicted_': 42,
#  '>64_630_738_567_34.5:NM_001019394 M_phase_phosphoprotein_6_family_protein': 35,
#  '>80_2989_3136_2910_36.6:NM_001019393 metallopeptidase__predicted_': 37,
#  '>121_1344_1405_1224_37.4:NM_001019392 mitochondrial_NTPase_Ylf2__predicted_': 37,
#  '>323_2197_2588_1875_36.4:NM_001019391 BRCT_domain_protein': 36,
#  '>528_1154_1296_627_35.7:NM_001019390 2__3__cyclic_nucleotide_3__phosphodiesterase__predicted_': 36,
#  '>98_2932_3169_2835_43.1:NM_001019389 alpha_alpha_trehalose_phosphate_synthase__predicted_': 43,
#  '>933_1262_2532_330_37.3:NM_001019388 sequence_orphan': 37,
#  '>436_1656_1910_1221_39.3:NM_001019387 NAD_binding_dehydrogenase_family_protein': 39,
#  '>461_1666_2142_1206_39.0:NM_001019386 pyruvyl_transferase_pvg1': 39,
#  '>168_935_1589_768_35.3:NM_001019385 nicotinamide_N_methyltransferase_Nnt1__predicted_': 35,
#  '>449_1579_1812_1131_35.7:NM_001019384 esterase_lipase__predicted_': 36,
#  '>59_1564_1799_1506_34.0:NM_001019383 DNA_replication_protein_Cdc24': 34,
#  '>95_988_1266_894_33.8:NM_001019382 nuclear_envelope_protein_Brr6_Brl1': 34,
#  '>76_801_904_726_36.6:NM_001019381 sequence_orphan': 37,
#  '>69_1190_2421_1122_36.6:NM_001019380 U3_snoRNP_associated_protein_Cic1_Utp30_family__predicted_': 37,
#  '>302_3316_3506_3015_35.4:NM_001019379 DNA_mismatch_repair_protein': 35,
#  '>27_266_1183_240_32.5:NM_001019378 diphthamide_biosynthesis_protein_Dph3__predicted_': 33,
#  '>29_106_249_78_36.5:NM_001019377 60S_ribosomal_protein_L41': 37,
#  '>132_1292_1613_1161_37.1:NM_001019376 ribosome_biogenesis_protein_Ltv1__predicted_': 37,
#  '>131_1981_2057_1851_39.6:NM_001019375 GTP_binding_protein__HSR1_related__predicted_': 40,
#  '>67_339_3797_273_36.4:NM_001019374 Spo12_family_protein': 36,
#  '>592_2430_2681_1839_37.5:NM_001019373 UBA_domain_protein_Ucp6': 38,
#  '>729_1334_1572_606_32.8:NM_001019372 transcription_factor__predicted_': 33,
#  '>117_4553_4700_4437_38.4:NM_001019371 glutathione_S_conjugate_exporting_ATPase_Abc2': 38,
#  '>1181_2278_2938_1098_36.3:NM_001019370 pheromone_M_factor_receptor_Map3': 36,
#  ...}

# %%
type(bin_num)
# Out:
# int

# %%
type(cutoffs)
# Out:
# list

# %%
type(seq_GC)
# Out:
# dict

# %%
metaout = "meta.lst"
logfile = "gms.log"
seq = "sequence"
start_prefix = "startseq."
gibbs_prefix = "gibbs_out."
mod_prefix = "itr_"
mod_suffix = ".mod"
hmmout_prefix = "itr_"
hmmout_suffix = ".lst"
out_name = "GeneMark_hmm.mod"
out_name_heuristic = "GeneMark_hmm_heuristic.mod"
out_suffix = "_hmm.mod"
out_suffix_heu = "_hmm_heuristic.mod"
fnn_out = ""
faa_out = ""

meta_out = "initial.meta.lst"
gc_out = f"{meta_out}.feature"

# %%
import sys
import os
import click
import re
import logging
from typing import Optional, List, Tuple, Dict
import logging
from subprocess import run
import pyfaidx
from Bio.SeqUtils import GC as getGC
from sortedcontainers import SortedDict
from tempfile import TemporaryDirectory

# %%
os.path.abspath("../utilities/probuild")
# Out:
# '/Users/milessmith/workspace/pygmst/pygmst/utilities/probuild'

# %%
probuild = os.path.abspath("../utilities/probuild")
gmhmmp = os.path.abspath("../utilities/gmhmmp")
meta_model = os.path.abspath("../models/MetaGeneMark_v1.mod")

# %%
def train(
    input_seq: str = "test.fa",
    seq: str = "sequence",
    motif: bool = True,
    fixmotif: bool = True,
    order: int = 4,
    order_non: int = 2,
    start_prefix: str  = "startseq.",
    gibbs_prefix: str = "itr_",
    prestart: int = 6,
    width: int = 12,
    build_cmd: str = f"{probuild} --par par_1.default",
    hmm_cmd: str = f"{gmhmmp} -s -d",
    par: str = "par_1.default",
    maxitr: int = 10,
    identity: float = 0.99,
) -> Tuple[str, List[str]]:
    tmp_files: List[str] = list()
    # ------------------------------------------------
    # prepare sequence
    # build_cmd should have the form of! `probuild --par par_1.default`
    # so this makes the below
    # `probuild --par par_1.default --clean_join sequence --seq test.fa`
    # which seems kind of redundant, but what do I know
    run(f"{build_cmd} --clean_join {seq} --seq {input_seq}".split())
    # TODO: another thing to restore when we figure out logging.
    # run([build_cmd, "--clean_join", seq, "--seq", input_seq, "--log", logfile])

    # ------------------------------------------------
    # tmp solution: get sequence size, get minimum sequence size from --par <file>
    # compare, skip iterations if short

    with open(seq, "r") as _:
        sequence_size = len(_.read())

    min_size_find_cmd = run(args=[f"grep MIN_SEQ_SIZE {par}".split()], capture_output=True)
    minimum_sequence_size = re.findall(
        pattern="\s*--MIN_SEQ_SIZE\s+", string=str(min_size_find_cmd.stdout, "utf=8")
    )[0]

    do_iterations = True

    if sequence_size < minimum_sequence_size:
        # form of! `probuild --par par_1.default --clean_join sequence --seq test.fa --MIN_CONTIG_SIZE 0 --GAP_FILLER
        run(f"{build_cmd} --clean_join {seq} --seq {input_seq} --MIN_CONTIG_SIZE 0 --GAP_FILLER".split())
        # run([build_cmd, "--clean_join", seq, "--seq", input_seq, "--log", logfile, "--MIN_CONTIG_SIZE", 0, "--GAP_FILLER"])
        do_iterations = False

    # Log("do_iterations = $do_iterations\n")

    # ------------------------------------------------
    # run initial prediction
    itr = 0
    next_item = f"{hmmout_prefix}{itr}{hmmout_suffix}"
    print("run initial prediction")

    # form of! `gmhmmp -s -d sequence -m MetaGeneMark_v1.mod -o itr_{itr}.lst`
    run(f"{hmm_cmd} {seq} -m {os.path.abspath('../models/MetaGeneMark_v1.mod')} -o {next_item}".split())
    # TODO: tempfile
    tmp_files.extend((next_item))

    # ------------------------------------------------
    # enter iterations loop

    # TODO: logfile
    # &Log( "entering iteration loop\n" );

    while do_iterations:
        itr += 1
        mod = f"{mod_prefix}{itr}{mod_suffix}"

        if motif and not fixmotif:
            start_seq = f"{start_prefix}{itr}"
            gibbs_out = f"{gibbs_prefix}{itr}"

        command = f"{build_cmd} --mkmod {mod} --seq {seq} --geneset {next_item} --ORDM {order} --order_non {order_non} --revcomp_non 1"

        if motif and not fixmotif:
            command = f"{command} --pre_start {start_seq} --PRE_START_WIDTH {prestart}"
        elif motif and fixmotif:
            command = (
                f"{command} --fixmotif --PRE_START_WIDTH {prestart} --width {width}"
            )
            # command += f" --fixmotif --PRE_START_WIDTH {prestart} --width {width} --log {logfile}"

        print(f"build model: {mod} for iteration: {itr}")
        run(command.split())
        tmp_files.extend((mod))

        if (
            motif and not fixmotif
        ):  # given that we only have Gibbs3, don't *really* have an option
            # if $gibbs_version == 1:
            #     &RunSystem( "$gibbs $start_seq $width -n > $gibbs_out", "run gibbs sampler\n" )
            # elif $gibbs_version == 3:
            #     &RunSystem( "$gibbs3 $start_seq $width -o $gibbs_out -F -Z  -n -r -y -x -m -s 1 -w 0.01", "run gibbs3 sampler\n" )
            print("run gibbs3 sampler")
            # form of! 'Gibbs3 startseq.{itr} 12 -o gibbs_out.{itr} -F -Z -n -r -y -x -m -s 1 -w 0.01"
            run(f"{gibbs3} {start_seq} {width} -o {gibbs_out} -F -Z -n -r -y -x -m -s 1 -w 0.01".split())
            tmp_files.extend((start_seq))

            print("make prestart model")
            # TODO: logfile
            # run([build_cmd, "--gibbs", gibbs_out, "--mod", mod, "--seq", start_seq, "--log", logfile])
            # form of! `probuild --par par_1.default --gibs gibbs_out.{itr} --mod itr_{itr}.mod --seq startseq.{itr}
            run(f"{build_cmd} --gibbs {gibbs_out} --mod {mod} --seq {start_seq}".split())
            tmp_files.extend((gibbs_out))

        prev = next_item
        # next_item = itr_{itr}.lst
        next_item = f"{hmmout_prefix}{itr}{hmmout_suffix}"

        # form of! `gmhmmp -s d sequence -m itr_{itr}.mod -o itr_{itr}.lst
        command = f"{hmm_cmd} {seq} -m {mod} -o {next_item}"

        # form of! `gmhmmp -s d sequence -m itr_{itr}.mod -o itr_{itr}.lst -r
        if motif:
            command += " -r"

        print(f"prediction, iteration: {itr}")
        run(command.split())
        tmp_files.extend((next_item))

        # `probuild --par par_1.default --compare --source itr_{itr}.lst --target itr_{itr-1}.lst
        command = f"{build_cmd} --compare --source {next_item} --target {prev}"
        # &Log( "compare:\n" . $command . "\n" );

        diff = str(run(command.split(), capture_output=True).stdout).strip()
        # &Log( "compare $prev and $next_item: $diff\n" );

        if diff >= identity:
            # &Log( "Stopped iterations on identity: $diff\n" );
            do_iterations = False
        if itr == maxitr:
            # &Log( "Stopped iterations on maximum number: $maxitr\n" )
            do_iterations = False
    return mod, tmp_files

# %%
list_of_temp = list()
model, list_of_temp = train()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-9427be462a45> in <module>
#       1 list_of_temp = list()
# ----> 2 model, list_of_temp = train()
#
# <ipython-input-35-23936c15e333> in train(input_seq, seq, motif, fixmotif, order, order_non, start_prefix, gibbs_prefix, prestart, width, build_cmd, hmm_cmd, par, maxitr, identity)
#      23     # `probuild --par par_1.default --clean_join sequence --seq test.fa`
#      24     # which seems kind of redundant, but what do I know
# ---> 25     run(f"{build_cmd} --clean_join {seq} --seq {input_seq}".split())
#      26     # TODO: another thing to restore when we figure out logging.
#      27     # run([build_cmd, "--clean_join", seq, "--seq", input_seq, "--log", logfile])
#
# ~/miniconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     487         kwargs['stderr'] = PIPE
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#     491             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~/miniconda3/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     852                             encoding=encoding, errors=errors)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#     856                                 startupinfo, creationflags, shell,
#
# ~/miniconda3/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1700                     if errno_num != 0:
#    1701                         err_msg = os.strerror(errno_num)
# -> 1702                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1703                 raise child_exception_type(err_msg)
#    1704
#
# OSError: [Errno 8] Exec format error: '../utilities/probuild'
